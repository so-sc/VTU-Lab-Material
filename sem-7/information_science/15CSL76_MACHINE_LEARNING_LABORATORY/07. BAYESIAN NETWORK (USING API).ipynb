# %%
from pgmpy.models import BayesianModel
cancer_model = BayesianModel([('Pollution', 'Cancer'),('Smoker', 'Cancer'),('Cancer', 'Xray'),('Cancer', 'Dyspnoea')])

# %%
print(cancer_model)

# %%
cancer_model.nodes()
# Out:
# NodeView(('Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea'))

# %%
cancer_model.edges()
# Out:
# OutEdgeView([('Pollution', 'Cancer'), ('Cancer', 'Xray'), ('Cancer', 'Dyspnoea'), ('Smoker', 'Cancer')])

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD

cpd_poll = TabularCPD(variable='Pollution', variable_card=2,values=[[0.9], [0.1]])
cpd_smoke = TabularCPD(variable='Smoker', variable_card=2,values=[[0.3], [0.7]])
cpd_cancer = TabularCPD(variable='Cancer', variable_card=2,values=[[0.03, 0.05, 0.001, 0.02],[0.97, 0.95, 0.999, 0.98]],
                        evidence=['Smoker', 'Pollution'],evidence_card=[2, 2])
cpd_xray = TabularCPD(variable='Xray', variable_card=2,values=[[0.9, 0.2], [0.1, 0.8]],evidence=['Cancer'], evidence_card=[2])
cpd_dysp = TabularCPD(variable='Dyspnoea', variable_card=2,values=[[0.65, 0.3], [0.35, 0.7]],evidence=['Cancer'], evidence_card=[2])

# %%
# Associating the parameters with the model structure.
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)
# Checking if the cpds are valid for the model.
cancer_model.check_model()
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x7f72a6986198>,
#  <TabularCPD representing P(Smoker:2) at 0x7f72a6986160>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x7f72b7025be0>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x7f72a6986128>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x7f72a6986208>]

# %%
print(cancer_model.get_cpds('Pollution'))
print(cancer_model.get_cpds('Smoker'))
print(cancer_model.get_cpds('Xray'))
print(cancer_model.get_cpds('Dyspnoea'))
print(cancer_model.get_cpds('Cancer'))
# Out:
# +-------------+-----+
# | Pollution_0 | 0.9 |
# +-------------+-----+
# | Pollution_1 | 0.1 |
# +-------------+-----+
# +----------+-----+
# | Smoker_0 | 0.3 |
# +----------+-----+
# | Smoker_1 | 0.7 |
# +----------+-----+
# +--------+----------+----------+
# | Cancer | Cancer_0 | Cancer_1 |
# +--------+----------+----------+
# | Xray_0 | 0.9      | 0.2      |
# +--------+----------+----------+
# | Xray_1 | 0.1      | 0.8      |
# +--------+----------+----------+
# +------------+----------+----------+
# | Cancer     | Cancer_0 | Cancer_1 |
# +------------+----------+----------+
# | Dyspnoea_0 | 0.65     | 0.3      |
# +------------+----------+----------+
# | Dyspnoea_1 | 0.35     | 0.7      |
# +------------+----------+----------+
# +-----------+-------------+-------------+-------------+-------------+
# | Smoker    | Smoker_0    | Smoker_0    | Smoker_1    | Smoker_1    |
# +-----------+-------------+-------------+-------------+-------------+
# | Pollution | Pollution_0 | Pollution_1 | Pollution_0 | Pollution_1 |
# +-----------+-------------+-------------+-------------+-------------+
# | Cancer_0  | 0.03        | 0.05        | 0.001       | 0.02        |
# +-----------+-------------+-------------+-------------+-------------+
# | Cancer_1  | 0.97        | 0.95        | 0.999       | 0.98        |
# +-----------+-------------+-------------+-------------+-------------+

# %%
cancer_model.local_independencies('Xray')
cancer_model.local_independencies('Pollution')
cancer_model.local_independencies('Smoker')
cancer_model.local_independencies('Dyspnoea')
cancer_model.local_independencies('Cancer')
# Out:
# (Cancer _|_ Dyspnoea, Xray | Smoker, Pollution)

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Dyspnoea, Xray | Cancer)
# (Pollution _|_ Dyspnoea | Cancer, Xray)
# (Pollution _|_ Dyspnoea, Xray | Smoker, Cancer)
# (Pollution _|_ Xray | Dyspnoea, Cancer)
# (Pollution _|_ Dyspnoea | Cancer, Smoker, Xray)
# (Pollution _|_ Xray | Smoker, Dyspnoea, Cancer)
# (Smoker _|_ Pollution)
# (Smoker _|_ Dyspnoea, Xray | Cancer)
# (Smoker _|_ Dyspnoea | Cancer, Xray)
# (Smoker _|_ Xray | Dyspnoea, Cancer)
# (Smoker _|_ Dyspnoea, Xray | Cancer, Pollution)
# (Smoker _|_ Dyspnoea | Cancer, Pollution, Xray)
# (Smoker _|_ Xray | Cancer, Dyspnoea, Pollution)
# (Xray _|_ Smoker, Dyspnoea, Pollution | Cancer)
# (Xray _|_ Dyspnoea, Pollution | Smoker, Cancer)
# (Xray _|_ Smoker, Pollution | Dyspnoea, Cancer)
# (Xray _|_ Smoker, Dyspnoea | Cancer, Pollution)
# (Xray _|_ Pollution | Smoker, Dyspnoea, Cancer)
# (Xray _|_ Dyspnoea | Cancer, Smoker, Pollution)
# (Xray _|_ Smoker | Cancer, Dyspnoea, Pollution)
# (Dyspnoea _|_ Xray, Smoker, Pollution | Cancer)
# (Dyspnoea _|_ Smoker, Pollution | Cancer, Xray)
# (Dyspnoea _|_ Xray, Pollution | Smoker, Cancer)
# (Dyspnoea _|_ Smoker, Xray | Cancer, Pollution)
# (Dyspnoea _|_ Pollution | Cancer, Smoker, Xray)
# (Dyspnoea _|_ Smoker | Cancer, Pollution, Xray)
# (Dyspnoea _|_ Xray | Cancer, Smoker, Pollution)

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
cancer_infer = VariableElimination(cancer_model)

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# +----------+---------------+
# | Cancer   |   phi(Cancer) |
# +==========+===============+
# | Cancer_0 |        0.0029 |
# +----------+---------------+
# | Cancer_1 |        0.9971 |
# +----------+---------------+
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:598: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi1.values = phi1.values[slice_]

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1,'Pollution': 1})
print(q['Cancer'])
# Out:
# +----------+---------------+
# | Cancer   |   phi(Cancer) |
# +==========+===============+
# | Cancer_0 |        0.0200 |
# +----------+---------------+
# | Cancer_1 |        0.9800 |
# +----------+---------------+

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt # Visuals
import seaborn as sns 
import sklearn as skl
import pandas as pd

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
np.set_printoptions(threshold=sys.maxsize) #see a whole array when we output it
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names) #gets Cleveland data

# %%
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']

heartDisease = heartDisease.replace('?', np.nan)

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), 
                       ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),
                      ('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])

# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
 #   print("CPD of {variable}:".format(variable=cpd.variable))
  #  print(cpd)
# Out:
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/estimators/base.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   states = sorted(list(self.data.ix[:, variable].dropna().unique()))
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/estimators/base.py:116: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   state_count_data = data.ix[:, variable].value_counts()
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/estimators/MLE.py:128: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   state_counts.ix[:, (state_counts == 0).all()] = 1

# %%
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# --------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+
# exang, trestbps, age, fbs | restecg, heartdisease, sex, chol)
# (thalach _|_ restecg, exang, trestbps, fbs | heartdisease, sex, chol, age)
# (thalach _|_ restecg, trestbps, age, fbs | heartdisease, sex, exang, chol)
# (thalach _|_ exang, trestbps, chol, age | restecg, heartdisease, sex, fbs)
# (thalach _|_ restecg, exang, trestbps, chol | heartdisease, sex, age, fbs)
# (thalach _|_ restecg, trestbps, chol, age | heartdisease, sex, exang, fbs)
# (thalach _|_ exang, trestbps, chol, fbs | restecg, heartdisease, sex, age)
# (thalach _|_ trestbps, chol, age, fbs | restecg, heartdisease, sex, exang)
# (thalach _|_ restecg, trestbps, chol, fbs | heartdisease, sex, exang, age)
# (thalach _|_ restecg, exang, sex, age | heartdisease, trestbps, chol, fbs)
# (thalach _|_ exang, sex, age, fbs | restecg, heartdisease, trestbps, chol)
# (thalach _|_ restecg, exang, sex, fbs | heartdisease, trestbps, chol, age)
# (thalach _|_ restecg, sex, age, fbs | heartdisease, trestbps, exang, chol)
# (thalach _|_ exang, sex, chol, age | restecg, heartdisease, trestbps, fbs)
# (thalach _|_ restecg, exang, sex, chol | heartdisease, trestbps, age, fbs)
# (thalach _|_ restecg, sex, chol, age | heartdisease, trestbps, exang, fbs)
# (thalach _|_ exang, sex, chol, fbs | restecg, heartdisease, trestbps, age)
# (thalach _|_ sex, chol, age, fbs | restecg, heartdisease, trestbps, exang)
# (thalach _|_ restecg, sex, chol, fbs | heartdisease, trestbps, exang, age)
# (thalach _|_ exang, sex, trestbps, age | restecg, heartdisease, chol, fbs)
# (thalach _|_ restecg, exang, sex, trestbps | heartdisease, chol, age, fbs)
# (thalach _|_ restecg, sex, trestbps, age | heartdisease, exang, chol, fbs)
# (thalach _|_ exang, sex, trestbps, fbs | restecg, heartdisease, chol, age)
# (thalach _|_ sex, trestbps, age, fbs | restecg, heartdisease, exang, chol)
# (thalach _|_ restecg, sex, trestbps, fbs | heartdisease, exang, chol, age)
# (thalach _|_ exang, sex, trestbps, chol | restecg, heartdisease, age, fbs)
# (thalach _|_ sex, trestbps, chol, age | restecg, heartdisease, exang, fbs)
# (thalach _|_ restecg, sex, trestbps, chol | heartdisease, exang, age, fbs)
# (thalach _|_ sex, trestbps, chol, fbs | restecg, heartdisease, exang, age)
# (thalach _|_ exang, age | sex, trestbps, chol, fbs)
# (thalach _|_ exang | sex, trestbps, chol, age)
# (thalach _|_ exang, age | restecg, sex, trestbps, fbs)
# (thalach _|_ exang | sex, trestbps, age, fbs)
# (thalach _|_ age | exang, sex, trestbps, fbs)
# (thalach _|_ exang | restecg, sex, trestbps, age)
# (thalach _|_ exang, sex, age | restecg, trestbps, chol, fbs)
# (thalach _|_ exang, sex | trestbps, chol, age, fbs)
# (thalach _|_ sex, age | exang, trestbps, chol, fbs)
# (thalach _|_ exang, sex | restecg, trestbps, chol, age)
# (thalach _|_ sex | exang, trestbps, chol, age)
# (thalach _|_ exang, sex | restecg, trestbps, age, fbs)
# (thalach _|_ sex, age | restecg, exang, trestbps, fbs)
# (thalach _|_ sex | exang, trestbps, age, fbs)
# (thalach _|_ sex | restecg, exang, trestbps, age)
# (thalach _|_ restecg, exang, age | heartdisease, sex, trestbps, chol, fbs)
# (thalach _|_ exang, age, fbs | heartdisease, sex, trestbps, chol, restecg)
# (thalach _|_ restecg, exang, fbs | heartdisease, sex, trestbps, chol, age)
# (thalach _|_ restecg, age, fbs | heartdisease, sex, trestbps, chol, exang)
# (thalach _|_ exang, chol, age | heartdisease, sex, trestbps, fbs, restecg)
# (thalach _|_ restecg, exang, chol | heartdisease, sex, trestbps, fbs, age)
# (thalach _|_ restecg, chol, age | heartdisease, sex, trestbps, fbs, exang)
# (thalach _|_ exang, chol, fbs | heartdisease, sex, trestbps, restecg, age)
# (thalach _|_ chol, age, fbs | heartdisease, sex, trestbps, restecg, exang)
# (thalach _|_ restecg, chol, fbs | heartdisease, sex, trestbps, age, exang)
# (thalach _|_ exang, trestbps, age | heartdisease, sex, chol, fbs, restecg)
# (thalach _|_ restecg, exang, trestbps | heartdisease, sex, chol, fbs, age)
# (thalach _|_ restecg, trestbps, age | heartdisease, sex, chol, fbs, exang)
# (thalach _|_ exang, trestbps, fbs | heartdisease, sex, chol, restecg, age)
# (thalach _|_ trestbps, age, fbs | heartdisease, sex, chol, restecg, exang)
# (thalach _|_ restecg, trestbps, fbs | heartdisease, sex, chol, age, exang)
# (thalach _|_ exang, trestbps, chol | heartdisease, sex, fbs, restecg, age)
# (thalach _|_ trestbps, chol, age | heartdisease, sex, fbs, restecg, exang)
# (thalach _|_ restecg, trestbps, chol | heartdisease, sex, fbs, age, exang)
# (thalach _|_ trestbps, chol, fbs | heartdisease, sex, restecg, age, exang)
# (thalach _|_ exang, sex, age | heartdisease, trestbps, chol, fbs, restecg)
# (thalach _|_ restecg, exang, sex | heartdisease, trestbps, chol, fbs, age)
# (thalach _|_ restecg, sex, age | heartdisease, trestbps, chol, fbs, exang)
# (thalach _|_ exang, sex, fbs | heartdisease, trestbps, chol, restecg, age)
# (thalach _|_ sex, age, fbs | heartdisease, trestbps, chol, restecg, exang)
# (thalach _|_ restecg, sex, fbs | heartdisease, trestbps, chol, age, exang)
# (thalach _|_ exang, sex, chol | heartdisease, trestbps, fbs, restecg, age)
# (thalach _|_ sex, chol, age | heartdisease, trestbps, fbs, restecg, exang)
# (thalach _|_ restecg, sex, chol | heartdisease, trestbps, fbs, age, exang)
# (thalach _|_ sex, chol, fbs | heartdisease, trestbps, restecg, age, exang)
# (thalach _|_ exang, sex, trestbps | heartdisease, chol, fbs, restecg, age)
# (thalach _|_ sex, trestbps, age | heartdisease, chol, fbs, restecg, exang)
# (thalach _|_ restecg, sex, trestbps | heartdisease, chol, fbs, age, exang)
# (thalach _|_ sex, trestbps, fbs | heartdisease, chol, restecg, age, exang)
# (thalach _|_ sex, trestbps, chol | heartdisease, fbs, restecg, age, exang)
# (thalach _|_ exang, age | sex, trestbps, chol, fbs, restecg)
# (thalach _|_ exang | sex, trestbps, chol, fbs, age)
# (thalach _|_ age | sex, trestbps, chol, fbs, exang)
# (thalach _|_ exang | sex, trestbps, chol, restecg, age)
# (thalach _|_ exang | sex, trestbps, fbs, restecg, age)
# (thalach _|_ age | sex, trestbps, fbs, restecg, exang)
# (thalach _|_ exang, sex | trestbps, chol, fbs, restecg, age)
# (thalach _|_ sex, age | trestbps, chol, fbs, restecg, exang)
# (thalach _|_ sex | trestbps, chol, fbs, age, exang)
# (thalach _|_ sex | trestbps, chol, restecg, age, exang)
# (thalach _|_ sex | trestbps, fbs, restecg, age, exang)
# (thalach _|_ exang, age | heartdisease, sex, trestbps, chol, fbs, restecg)
# (thalach _|_ restecg, exang | heartdisease, sex, trestbps, chol, fbs, age)
# (thalach _|_ restecg, age | heartdisease, sex, trestbps, chol, fbs, exang)
# (thalach _|_ exang, fbs | heartdisease, sex, trestbps, chol, restecg, age)
# (thalach _|_ age, fbs | heartdisease, sex, trestbps, chol, restecg, exang)
# (thalach _|_ restecg, fbs | heartdisease, sex, trestbps, chol, age, exang)
# (thalach _|_ exang, chol | heartdisease, sex, trestbps, fbs, restecg, age)
# (thalach _|_ chol, age | heartdisease, sex, trestbps, fbs, restecg, exang)
# (thalach _|_ restecg, chol | heartdisease, sex, trestbps, fbs, age, exang)
# (thalach _|_ chol, fbs | heartdisease, sex, trestbps, restecg, age, exang)
# (thalach _|_ exang, trestbps | heartdisease, sex, chol, fbs, restecg, age)
# (thalach _|_ trestbps, age | heartdisease, sex, chol, fbs, restecg, exang)
# (thalach _|_ restecg, trestbps | heartdisease, sex, chol, fbs, age, exang)
# (thalach _|_ trestbps, fbs | heartdisease, sex, chol, restecg, age, exang)
# (thalach _|_ trestbps, chol | heartdisease, sex, fbs, restecg, age, exang)
# (thalach _|_ exang, sex | heartdisease, trestbps, chol, fbs, restecg, age)
# (thalach _|_ sex, age | heartdisease, trestbps, chol, fbs, restecg, exang)
# (thalach _|_ restecg, sex | heartdisease, trestbps, chol, fbs, age, exang)
# (thalach _|_ sex, fbs | heartdisease, trestbps, chol, restecg, age, exang)
# (thalach _|_ sex, chol | heartdisease, trestbps, fbs, restecg, age, exang)
# (thalach _|_ sex, trestbps | heartdisease, chol, fbs, restecg, age, exang)
# (thalach _|_ exang | sex, trestbps, chol, fbs, restecg, age)
# (thalach _|_ age | sex, trestbps, chol, fbs, restecg, exang)
# (thalach _|_ sex | trestbps, chol, fbs, restecg, age, exang)
# (thalach _|_ exang | heartdisease, sex, trestbps, chol, fbs, restecg, age)
# (thalach _|_ age | heartdisease, sex, trestbps, chol, fbs, restecg, exang)
# (thalach _|_ restecg | heartdisease, sex, trestbps, chol, fbs, age, exang)
# (thalach _|_ fbs | heartdisease, sex, trestbps, chol, restecg, age, exang)
# (thalach _|_ chol | heartdisease, sex, trestbps, fbs, restecg, age, exang)
# (thalach _|_ trestbps | heartdisease, sex, chol, fbs, restecg, age, exang)
# (thalach _|_ sex | heartdisease, trestbps, chol, fbs, restecg, age, exang)
# (chol _|_ exang, sex, trestbps, thalach, fbs, restecg, age | heartdisease)
# (chol _|_ exang, thalach, trestbps, fbs, restecg, age | heartdisease, sex)
# (chol _|_ exang, sex, thalach, fbs, restecg, age | heartdisease, trestbps)
# (chol _|_ exang, sex, trestbps, thalach, restecg, age | heartdisease, fbs)
# (chol _|_ exang, sex, trestbps, thalach, fbs, age | restecg, heartdisease)
# (chol _|_ exang, sex, trestbps, thalach, fbs, restecg | heartdisease, age)
# (chol _|_ thalach, sex, trestbps, fbs, restecg, age | heartdisease, exang)
# (chol _|_ exang, sex, trestbps, fbs, restecg, age | thalach, heartdisease)
# (chol _|_ exang, sex, age | trestbps, fbs)
# (chol _|_ exang, sex | trestbps, age)
# (chol _|_ exang, thalach, fbs, restecg, age | heartdisease, sex, trestbps)
# (chol _|_ exang, thalach, trestbps, restecg, age | heartdisease, sex, fbs)
# (chol _|_ thalach, exang, trestbps, fbs, age | restecg, heartdisease, sex)
# (chol _|_ exang, thalach, trestbps, fbs, restecg | heartdisease, sex, age)
# (chol _|_ thalach, trestbps, fbs, restecg, age | heartdisease, sex, exang)
# (chol _|_ exang, trestbps, fbs, restecg, age | thalach, heartdisease, sex)
# (chol _|_ exang, sex, thalach, restecg, age | heartdisease, trestbps, fbs)
# (chol _|_ thalach, sex, exang, fbs, age | restecg, heartdisease, trestbps)
# (chol _|_ exang, sex, thalach, fbs, restecg | heartdisease, trestbps, age)
# (chol _|_ thalach, sex, fbs, restecg, age | heartdisease, trestbps, exang)
# (chol _|_ exang, sex, fbs, restecg, age | thalach, heartdisease, trestbps)
# (chol _|_ thalach, sex, trestbps, exang, age | restecg, heartdisease, fbs)
# (chol _|_ exang, sex, trestbps, thalach, restecg | heartdisease, age, fbs)
# (chol _|_ thalach, sex, trestbps, restecg, age | heartdisease, exang, fbs)
# (chol _|_ exang, sex, trestbps, restecg, age | thalach, heartdisease, fbs)
# (chol _|_ thalach, sex, trestbps, exang, fbs | restecg, heartdisease, age)
# (chol _|_ thalach, sex, trestbps, fbs, age | restecg, heartdisease, exang)
# (chol _|_ exang, sex, trestbps, fbs, age | restecg, heartdisease, thalach)
# (chol _|_ thalach, sex, trestbps, fbs, restecg | heartdisease, exang, age)
# (chol _|_ exang, sex, trestbps, fbs, restecg | thalach, heartdisease, age)
# (chol _|_ sex, trestbps, fbs, restecg, age | thalach, heartdisease, exang)
# (chol _|_ exang, age | sex, trestbps, fbs)
# (chol _|_ exang | sex, trestbps, age)
# (chol _|_ exang, sex, age | restecg, trestbps, fbs)
# (chol _|_ exang, sex | trestbps, age, fbs)
# (chol _|_ sex, age | exang, trestbps, fbs)
# (chol _|_ exang, sex, age | thalach, trestbps, fbs)
# (chol _|_ exang, sex | restecg, trestbps, age)
# (chol _|_ sex | exang, trestbps, age)
# (chol _|_ exang, sex | thalach, trestbps, age)
# (chol _|_ restecg, exang, thalach, age | heartdisease, sex, trestbps, fbs)
# (chol _|_ thalach, exang, age, fbs | restecg, heartdisease, sex, trestbps)
# (chol _|_ restecg, exang, thalach, fbs | heartdisease, sex, trestbps, age)
# (chol _|_ restecg, thalach, age, fbs | heartdisease, sex, trestbps, exang)
# (chol _|_ restecg, exang, age, fbs | thalach, heartdisease, sex, trestbps)
# (chol _|_ thalach, trestbps, exang, age | restecg, heartdisease, sex, fbs)
# (chol _|_ restecg, exang, trestbps, thalach | heartdisease, sex, age, fbs)
# (chol _|_ restecg, thalach, trestbps, age | heartdisease, sex, exang, fbs)
# (chol _|_ restecg, exang, trestbps, age | thalach, heartdisease, sex, fbs)
# (chol _|_ thalach, trestbps, exang, fbs | restecg, heartdisease, sex, age)
# (chol _|_ thalach, trestbps, age, fbs | restecg, heartdisease, sex, exang)
# (chol _|_ exang, trestbps, age, fbs | restecg, heartdisease, sex, thalach)
# (chol _|_ restecg, thalach, trestbps, fbs | heartdisease, sex, exang, age)
# (chol _|_ restecg, exang, trestbps, fbs | thalach, heartdisease, sex, age)
# (chol _|_ restecg, trestbps, age, fbs | thalach, heartdisease, sex, exang)
# (chol _|_ thalach, sex, exang, age | restecg, heartdisease, trestbps, fbs)
# (chol _|_ restecg, exang, sex, thalach | heartdisease, trestbps, age, fbs)
# (chol _|_ restecg, thalach, sex, age | heartdisease, trestbps, exang, fbs)
# (chol _|_ restecg, exang, sex, age | thalach, heartdisease, trestbps, fbs)
# (chol _|_ thalach, sex, exang, fbs | restecg, heartdisease, trestbps, age)
# (chol _|_ thalach, sex, age, fbs | restecg, heartdisease, trestbps, exang)
# (chol _|_ exang, sex, age, fbs | restecg, heartdisease, thalach, trestbps)
# (chol _|_ restecg, thalach, sex, fbs | heartdisease, trestbps, exang, age)
# (chol _|_ restecg, exang, sex, fbs | thalach, heartdisease, trestbps, age)
# (chol _|_ restecg, sex, age, fbs | thalach, heartdisease, trestbps, exang)
# (chol _|_ thalach, sex, trestbps, exang | restecg, heartdisease, age, fbs)
# (chol _|_ thalach, sex, trestbps, age | restecg, heartdisease, exang, fbs)
# (chol _|_ exang, sex, trestbps, age | restecg, heartdisease, thalach, fbs)
# (chol _|_ restecg, thalach, sex, trestbps | heartdisease, exang, age, fbs)
# (chol _|_ restecg, exang, sex, trestbps | thalach, heartdisease, age, fbs)
# (chol _|_ restecg, sex, trestbps, age | thalach, heartdisease, exang, fbs)
# (chol _|_ thalach, sex, trestbps, fbs | restecg, heartdisease, exang, age)
# (chol _|_ exang, sex, trestbps, fbs | restecg, heartdisease, thalach, age)
# (chol _|_ sex, trestbps, age, fbs | restecg, heartdisease, thalach, exang)
# (chol _|_ restecg, sex, trestbps, fbs | thalach, heartdisease, exang, age)
# (chol _|_ exang, age | restecg, sex, trestbps, fbs)
# (chol _|_ exang | sex, trestbps, age, fbs)
# (chol _|_ age | exang, sex, trestbps, fbs)
# (chol _|_ exang, age | thalach, sex, trestbps, fbs)
# (chol _|_ exang | restecg, sex, trestbps, age)
# (chol _|_ exang | thalach, sex, trestbps, age)
# (chol _|_ exang, sex | restecg, trestbps, age, fbs)
# (chol _|_ sex, age | restecg, exang, trestbps, fbs)
# (chol _|_ exang, sex, age | restecg, thalach, trestbps, fbs)
# (chol _|_ sex | exang, trestbps, age, fbs)
# (chol _|_ exang, sex | thalach, trestbps, age, fbs)
# (chol _|_ sex, age | thalach, exang, trestbps, fbs)
# (chol _|_ sex | restecg, exang, trestbps, age)
# (chol _|_ exang, sex | restecg, thalach, trestbps, age)
# (chol _|_ sex | thalach, exang, trestbps, age)
# (chol _|_ thalach, exang, age | heartdisease, sex, trestbps, fbs, restecg)
# (chol _|_ restecg, exang, thalach | heartdisease, sex, trestbps, fbs, age)
# (chol _|_ restecg, thalach, age | heartdisease, sex, trestbps, fbs, exang)
# (chol _|_ restecg, exang, age | heartdisease, sex, trestbps, fbs, thalach)
# (chol _|_ thalach, exang, fbs | heartdisease, sex, trestbps, restecg, age)
# (chol _|_ thalach, age, fbs | heartdisease, sex, trestbps, restecg, exang)
# (chol _|_ exang, age, fbs | heartdisease, sex, trestbps, restecg, thalach)
# (chol _|_ restecg, thalach, fbs | heartdisease, sex, trestbps, age, exang)
# (chol _|_ restecg, exang, fbs | heartdisease, sex, trestbps, age, thalach)
# (chol _|_ restecg, age, fbs | heartdisease, sex, trestbps, thalach, exang)
# (chol _|_ thalach, trestbps, exang | heartdisease, sex, fbs, restecg, age)
# (chol _|_ thalach, trestbps, age | heartdisease, sex, fbs, restecg, exang)
# (chol _|_ exang, trestbps, age | heartdisease, sex, fbs, restecg, thalach)
# (chol _|_ restecg, thalach, trestbps | heartdisease, sex, fbs, age, exang)
# (chol _|_ restecg, exang, trestbps | heartdisease, sex, fbs, age, thalach)
# (chol _|_ restecg, trestbps, age | heartdisease, sex, fbs, thalach, exang)
# (chol _|_ thalach, trestbps, fbs | heartdisease, sex, restecg, age, exang)
# (chol _|_ exang, trestbps, fbs | heartdisease, sex, restecg, age, thalach)
# (chol _|_ trestbps, age, fbs | heartdisease, sex, restecg, thalach, exang)
# (chol _|_ restecg, trestbps, fbs | heartdisease, sex, age, thalach, exang)
# (chol _|_ thalach, sex, exang | heartdisease, trestbps, fbs, restecg, age)
# (chol _|_ thalach, sex, age | heartdisease, trestbps, fbs, restecg, exang)
# (chol _|_ exang, sex, age | heartdisease, trestbps, fbs, restecg, thalach)
# (chol _|_ restecg, thalach, sex | heartdisease, trestbps, fbs, age, exang)
# (chol _|_ restecg, exang, sex | heartdisease, trestbps, fbs, age, thalach)
# (chol _|_ restecg, sex, age | heartdisease, trestbps, fbs, thalach, exang)
# (chol _|_ thalach, sex, fbs | heartdisease, trestbps, restecg, age, exang)
# (chol _|_ exang, sex, fbs | heartdisease, trestbps, restecg, age, thalach)
# (chol _|_ sex, age, fbs | heartdisease, trestbps, restecg, thalach, exang)
# (chol _|_ restecg, sex, fbs | heartdisease, trestbps, age, thalach, exang)
# (chol _|_ thalach, sex, trestbps | heartdisease, fbs, restecg, age, exang)
# (chol _|_ exang, sex, trestbps | heartdisease, fbs, restecg, age, thalach)
# (chol _|_ sex, trestbps, age | heartdisease, fbs, restecg, thalach, exang)
# (chol _|_ restecg, sex, trestbps | heartdisease, fbs, age, thalach, exang)
# (chol _|_ sex, trestbps, fbs | heartdisease, restecg, age, thalach, exang)
# (chol _|_ exang | sex, trestbps, fbs, restecg, age)
# (chol _|_ age | sex, trestbps, fbs, restecg, exang)
# (chol _|_ exang, age | sex, trestbps, fbs, restecg, thalach)
# (chol _|_ exang | sex, trestbps, fbs, age, thalach)
# (chol _|_ age | sex, trestbps, fbs, thalach, exang)
# (chol _|_ exang | sex, trestbps, restecg, age, thalach)
# (chol _|_ sex | trestbps, fbs, restecg, age, exang)
# (chol _|_ exang, sex | trestbps, fbs, restecg, age, thalach)
# (chol _|_ sex, age | trestbps, fbs, restecg, exang, thalach)
# (chol _|_ sex | trestbps, fbs, age, thalach, exang)
# (chol _|_ sex | trestbps, restecg, age, exang, thalach)
# (chol _|_ thalach, exang | heartdisease, sex, trestbps, fbs, restecg, age)
# (chol _|_ thalach, age | heartdisease, sex, trestbps, fbs, restecg, exang)
# (chol _|_ exang, age | heartdisease, sex, trestbps, fbs, restecg, thalach)
# (chol _|_ restecg, thalach | heartdisease, sex, trestbps, fbs, age, exang)
# (chol _|_ restecg, exang | heartdisease, sex, trestbps, fbs, age, thalach)
# (chol _|_ restecg, age | heartdisease, sex, trestbps, fbs, exang, thalach)
# (chol _|_ thalach, fbs | heartdisease, sex, trestbps, restecg, age, exang)
# (chol _|_ exang, fbs | heartdisease, sex, trestbps, restecg, age, thalach)
# (chol _|_ age, fbs | heartdisease, sex, trestbps, restecg, exang, thalach)
# (chol _|_ restecg, fbs | heartdisease, sex, trestbps, age, exang, thalach)
# (chol _|_ thalach, trestbps | heartdisease, sex, fbs, restecg, age, exang)
# (chol _|_ exang, trestbps | heartdisease, sex, fbs, restecg, age, thalach)
# (chol _|_ trestbps, age | heartdisease, sex, fbs, restecg, exang, thalach)
# (chol _|_ restecg, trestbps | heartdisease, sex, fbs, age, exang, thalach)
# (chol _|_ trestbps, fbs | heartdisease, sex, restecg, age, exang, thalach)
# (chol _|_ thalach, sex | heartdisease, trestbps, fbs, restecg, age, exang)
# (chol _|_ exang, sex | heartdisease, trestbps, fbs, restecg, age, thalach)
# (chol _|_ sex, age | heartdisease, trestbps, fbs, restecg, exang, thalach)
# (chol _|_ restecg, sex | heartdisease, trestbps, fbs, age, exang, thalach)
# (chol _|_ sex, fbs | heartdisease, trestbps, restecg, age, exang, thalach)
# (chol _|_ sex, trestbps | heartdisease, fbs, restecg, age, exang, thalach)
# (chol _|_ exang | sex, trestbps, fbs, restecg, age, thalach)
# (chol _|_ age | sex, trestbps, fbs, restecg, exang, thalach)
# (chol _|_ sex | trestbps, fbs, restecg, age, exang, thalach)
# (chol _|_ thalach | heartdisease, sex, trestbps, fbs, restecg, age, exang)
# (chol _|_ exang | heartdisease, sex, trestbps, fbs, restecg, age, thalach)
# (chol _|_ age | heartdisease, sex, trestbps, fbs, restecg, exang, thalach)
# (chol _|_ restecg | heartdisease, sex, trestbps, fbs, age, exang, thalach)
# (chol _|_ fbs | heartdisease, sex, trestbps, restecg, age, exang, thalach)
# (chol _|_ trestbps | heartdisease, sex, fbs, restecg, age, exang, thalach)
# (chol _|_ sex | heartdisease, trestbps, fbs, restecg, age, exang, thalach)

# %%
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# +----------------+---------------------+
# | heartdisease   |   phi(heartdisease) |
# +================+=====================+
# | heartdisease_0 |              0.6333 |
# +----------------+---------------------+
# | heartdisease_1 |              0.3667 |
# +----------------+---------------------+
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:598: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi1.values = phi1.values[slice_]
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# +----------------+---------------------+
# | heartdisease   |   phi(heartdisease) |
# +================+=====================+
# | heartdisease_0 |              1.0000 |
# +----------------+---------------------+
# | heartdisease_1 |              0.0000 |
# +----------------+---------------------+
