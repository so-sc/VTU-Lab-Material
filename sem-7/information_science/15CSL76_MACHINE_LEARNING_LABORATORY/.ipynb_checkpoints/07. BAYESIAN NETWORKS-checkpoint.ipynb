# %%
from pgmpy.models import BayesianModel
cancer_model = BayesianModel([('Pollution', 'Cancer'),('Smoker', 'Cancer'),('Cancer', 'Xray'),('Cancer', 'Dyspnoea')])
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-6c317d21b832> in <module>
# ----> 1 from pgmpy.models import BayesianModel
#       2 cancer_model = BayesianModel([('Pollution', 'Cancer'),('Smoker', 'Cancer'),('Cancer', 'Xray'),('Cancer', 'Dyspnoea')])
#
# ModuleNotFoundError: No module named 'pgmpy'

# %%
print(cancer_model)

# %%
cancer_model.nodes()

# %%
cancer_model.edges()
# Out:
# [('Pollution', 'Cancer'),
#  ('Cancer', 'Xray'),
#  ('Cancer', 'Dyspnoea'),
#  ('Smoker', 'Cancer')]

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD

cpd_poll = TabularCPD(variable='Pollution', variable_card=2,values=[[0.9], [0.1]])
cpd_smoke = TabularCPD(variable='Smoker', variable_card=2,values=[[0.3], [0.7]])
cpd_cancer = TabularCPD(variable='Cancer', variable_card=2,values=[[0.03, 0.05, 0.001, 0.02],[0.97, 0.95, 0.999, 0.98]],
                        evidence=['Smoker', 'Pollution'],evidence_card=[2, 2])
cpd_xray = TabularCPD(variable='Xray', variable_card=2,values=[[0.9, 0.2], [0.1, 0.8]],evidence=['Cancer'], evidence_card=[2])
cpd_dysp = TabularCPD(variable='Dyspnoea', variable_card=2,values=[[0.65, 0.3], [0.35, 0.7]],evidence=['Cancer'], evidence_card=[2])

# %%
# Associating the parameters with the model structure.
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)
# Checking if the cpds are valid for the model.
cancer_model.check_model()
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x1bf5656d160>,
#  <TabularCPD representing P(Smoker:2) at 0x1bf56620198>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x1bf566201d0>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x1bf56620160>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x1bf56620208>]

# %%
print(cancer_model.get_cpds('Pollution'))
print(cancer_model.get_cpds('Smoker'))
print(cancer_model.get_cpds('Xray'))
print(cancer_model.get_cpds('Dyspnoea'))
print(cancer_model.get_cpds('Cancer'))
# Out:
# ╒═════════════╤═════╕
# │ Pollution_0 │ 0.9 │
# ├─────────────┼─────┤
# │ Pollution_1 │ 0.1 │
# ╘═════════════╧═════╛
# ╒══════════╤═════╕
# │ Smoker_0 │ 0.3 │
# ├──────────┼─────┤
# │ Smoker_1 │ 0.7 │
# ╘══════════╧═════╛
# ╒════════╤══════════╤══════════╕
# │ Cancer │ Cancer_0 │ Cancer_1 │
# ├────────┼──────────┼──────────┤
# │ Xray_0 │ 0.9      │ 0.2      │
# ├────────┼──────────┼──────────┤
# │ Xray_1 │ 0.1      │ 0.8      │
# ╘════════╧══════════╧══════════╛
# ╒════════════╤══════════╤══════════╕
# │ Cancer     │ Cancer_0 │ Cancer_1 │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_0 │ 0.65     │ 0.3      │
# ├────────────┼──────────┼──────────┤
# │ Dyspnoea_1 │ 0.35     │ 0.7      │
# ╘════════════╧══════════╧══════════╛
# ╒═══════════╤═════════════╤═════════════╤═════════════╤═════════════╕
# │ Smoker    │ Smoker_0    │ Smoker_0    │ Smoker_1    │ Smoker_1    │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Pollution │ Pollution_0 │ Pollution_1 │ Pollution_0 │ Pollution_1 │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_0  │ 0.03        │ 0.05        │ 0.001       │ 0.02        │
# ├───────────┼─────────────┼─────────────┼─────────────┼─────────────┤
# │ Cancer_1  │ 0.97        │ 0.95        │ 0.999       │ 0.98        │
# ╘═══════════╧═════════════╧═════════════╧═════════════╧═════════════╛

# %%
cancer_model.local_independencies('Xray')
cancer_model.local_independencies('Pollution')
cancer_model.local_independencies('Smoker')
cancer_model.local_independencies('Dyspnoea')
cancer_model.local_independencies('Cancer')

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Xray, Dyspnoea | Cancer)
# (Pollution _|_ Xray, Dyspnoea | Cancer, Smoker)
# (Pollution _|_ Dyspnoea | Cancer, Xray)
# (Pollution _|_ Xray | Cancer, Dyspnoea)
# (Pollution _|_ Dyspnoea | Cancer, Smoker, Xray)
# (Pollution _|_ Xray | Cancer, Smoker, Dyspnoea)
# (Smoker _|_ Pollution)
# (Smoker _|_ Dyspnoea, Xray | Cancer)
# (Smoker _|_ Dyspnoea, Xray | Cancer, Pollution)
# (Smoker _|_ Xray | Cancer, Dyspnoea)
# (Smoker _|_ Dyspnoea | Cancer, Xray)
# (Smoker _|_ Xray | Cancer, Dyspnoea, Pollution)
# (Smoker _|_ Dyspnoea | Cancer, Xray, Pollution)
# (Xray _|_ Smoker, Dyspnoea, Pollution | Cancer)
# (Xray _|_ Smoker, Dyspnoea | Cancer, Pollution)
# (Xray _|_ Dyspnoea, Pollution | Cancer, Smoker)
# (Xray _|_ Smoker, Pollution | Cancer, Dyspnoea)
# (Xray _|_ Dyspnoea | Cancer, Smoker, Pollution)
# (Xray _|_ Smoker | Cancer, Dyspnoea, Pollution)
# (Xray _|_ Pollution | Cancer, Smoker, Dyspnoea)
# (Dyspnoea _|_ Smoker, Xray, Pollution | Cancer)
# (Dyspnoea _|_ Smoker, Xray | Cancer, Pollution)
# (Dyspnoea _|_ Xray, Pollution | Cancer, Smoker)
# (Dyspnoea _|_ Smoker, Pollution | Cancer, Xray)
# (Dyspnoea _|_ Xray | Cancer, Smoker, Pollution)
# (Dyspnoea _|_ Smoker | Cancer, Xray, Pollution)
# (Dyspnoea _|_ Pollution | Cancer, Smoker, Xray)

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination
cancer_infer = VariableElimination(cancer_model)

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0029 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9971 │
# ╘══════════╧═══════════════╛

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1,'Pollution': 1})
print(q['Cancer'])
# Out:
# ╒══════════╤═══════════════╕
# │ Cancer   │   phi(Cancer) │
# ╞══════════╪═══════════════╡
# │ Cancer_0 │        0.0200 │
# ├──────────┼───────────────┤
# │ Cancer_1 │        0.9800 │
# ╘══════════╧═══════════════╛

# %%
import numpy as np
from urllib.request import urlopen
import urllib
import matplotlib.pyplot as plt # Visuals
import seaborn as sns 
import sklearn as skl
import pandas as pd

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
np.set_printoptions(threshold=np.nan) #see a whole array when we output it
names = ['age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach', 'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease']
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL), names = names) #gets Cleveland data

# %%
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']

heartDisease = heartDisease.replace('?', np.nan)

# %%
from pgmpy.models import BayesianModel
from pgmpy.estimators import MaximumLikelihoodEstimator, BayesianEstimator

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'), ('sex', 'trestbps'), ('sex', 'trestbps'), 
                       ('exang', 'trestbps'),('trestbps','heartdisease'),('fbs','heartdisease'),
                      ('heartdisease','restecg'),('heartdisease','thalach'),('heartdisease','chol')])

# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
 #   print("CPD of {variable}:".format(variable=cpd.variable))
  #  print(cpd)

# %%
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# ╒═════════╤════════════╕
# │ age(28) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(29) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(30) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(31) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(32) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(33) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(34) │ 0.0153257  │
# ├─────────┼────────────┤
# │ age(35) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(36) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(37) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(38) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(39) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(40) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(41) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(42) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(43) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(44) │ 0.0268199  │
# ├─────────┼────────────┤
# │ age(45) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(46) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(47) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(48) │ 0.0613027  │
# ├─────────┼────────────┤
# │ age(49) │ 0.0421456  │
# ├─────────┼────────────┤
# │ age(50) │ 0.045977   │
# ├─────────┼────────────┤
# │ age(51) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(52) │ 0.0574713  │
# ├─────────┼────────────┤
# │ age(53) │ 0.0383142  │
# ├─────────┼────────────┤
# │ age(54) │ 0.0842912  │
# ├─────────┼────────────┤
# │ age(55) │ 0.0536398  │
# ├─────────┼────────────┤
# │ age(56) │ 0.0306513  │
# ├─────────┼────────────┤
# │ age(57) │ 0.0191571  │
# ├─────────┼────────────┤
# │ age(58) │ 0.0344828  │
# ├─────────┼────────────┤
# │ age(59) │ 0.0229885  │
# ├─────────┼────────────┤
# │ age(60) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(61) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(62) │ 0.00766284 │
# ├─────────┼────────────┤
# │ age(63) │ 0.00383142 │
# ├─────────┼────────────┤
# │ age(65) │ 0.0114943  │
# ├─────────┼────────────┤
# │ age(66) │ 0          │
# ╘═════════╧════════════╛
# ╒══════════════╤══════════════════════╤══════════════════════╕
# │ heartdisease │ heartdisease(0)      │ heartdisease(1)      │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(100)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(117)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(129)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(132)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(147)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(156)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(160)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(161)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(163)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(164)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(166)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(167)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(168)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(171)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(172)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(173)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(175)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(179)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(180)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(182)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(184)    │ 0.018404907975460124 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(186)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(187)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(188)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(190)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(193)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(194)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(195)    │ 0.018404907975460124 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(196)    │ 0.018404907975460124 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(198)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(200)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(201)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(202)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(204)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(205)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(206)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(207)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(208)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(209)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(210)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(211)    │ 0.018404907975460124 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(212)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(213)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(214)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(215)    │ 0.024539877300613498 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(216)    │ 0.012269938650306749 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(217)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(218)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(219)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(220)    │ 0.018404907975460124 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(221)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(222)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(223)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(224)    │ 0.018404907975460124 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(225)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(226)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(227)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(228)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(229)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(230)    │ 0.024539877300613498 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(231)    │ 0.0                  │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(233)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(234)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(237)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(238)    │ 0.024539877300613498 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(240)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(241)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(242)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(243)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(245)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(246)    │ 0.012269938650306749 │ 0.030612244897959183 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(247)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(248)    │ 0.0                  │ 0.030612244897959183 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(249)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(250)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(251)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(253)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(254)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(255)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(256)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(257)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(259)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(260)    │ 0.018404907975460124 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(263)    │ 0.006134969325153374 │ 0.030612244897959183 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(264)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(265)    │ 0.0                  │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(266)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(267)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(268)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(269)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(270)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(271)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(272)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(273)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(274)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(275)    │ 0.012269938650306749 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(276)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(277)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(279)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(280)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(281)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(282)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(283)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(284)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(285)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(287)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(288)    │ 0.0                  │ 0.030612244897959183 │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(289)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(290)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(291)    │ 0.006134969325153374 │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(292)    │ 0.012269938650306749 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(294)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(295)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(297)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(298)    │ 0.006134969325153374 │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(303)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(305)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(306)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(307)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(308)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(309)    │ 0.0                  │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(312)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(315)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(318)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(320)    │ 0.012269938650306749 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(326)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(328)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(329)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(331)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(336)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(338)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(339)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(340)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(341)    │ 0.0                  │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(342)    │ 0.0                  │ 0.02040816326530612  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(344)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(347)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(355)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(358)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(365)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(388)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(392)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(393)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(394)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(404)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(412)    │ 0.006134969325153374 │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(466)    │ 0.0                  │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(468)    │ 0.0                  │ 0.0                  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(491)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(518)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(529)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(603)    │ 0.0                  │ 0.01020408163265306  │
# ├──────────────┼──────────────────────┼──────────────────────┤
# │ chol(85)     │ 0.006134969325153374 │ 0.0                  │
# ╘══════════════╧══════════════════════╧══════════════════════╛
# ╒════════╤══════════╕
# │ sex(0) │ 0.264368 │
# ├────────┼──────────┤
# │ sex(1) │ 0.735632 │
# ╘════════╧══════════╛
# (age _|_ sex, exang)
# (age _|_ exang | sex)
# (age _|_ sex, exang | fbs)
# (age _|_ thalach, chol, restecg | heartdisease)
# (age _|_ sex | exang)
# (age _|_ thalach, restecg | chol, heartdisease)
# (age _|_ exang | sex, fbs)
# (age _|_ thalach, chol, restecg | heartdisease, sex)
# (age _|_ thalach, chol, restecg | heartdisease, fbs)
# (age _|_ thalach, chol, restecg, heartdisease | fbs, trestbps)
# (age _|_ sex | fbs, exang)
# (age _|_ thalach, chol | heartdisease, restecg)
# (age _|_ chol, restecg | thalach, heartdisease)
# (age _|_ thalach, chol, restecg | heartdisease, trestbps)
# (age _|_ thalach, chol, restecg | heartdisease, exang)
# (age _|_ thalach, restecg | chol, sex, heartdisease)
# (age _|_ thalach, restecg | chol, fbs, heartdisease)
# (age _|_ thalach, heartdisease, restecg | chol, fbs, trestbps)
# (age _|_ thalach | chol, restecg, heartdisease)
# (age _|_ restecg | thalach, chol, heartdisease)
# (age _|_ thalach, restecg | chol, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, heartdisease, exang)
# (age _|_ thalach, chol, restecg | heartdisease, sex, fbs)
# (age _|_ thalach, chol, restecg, heartdisease | sex, fbs, trestbps)
# (age _|_ thalach, chol | heartdisease, sex, restecg)
# (age _|_ chol, restecg | thalach, heartdisease, sex)
# (age _|_ thalach, chol, restecg | heartdisease, sex, trestbps)
# (age _|_ thalach, chol, restecg | heartdisease, sex, exang)
# (age _|_ thalach, chol | heartdisease, restecg, fbs)
# (age _|_ thalach, chol, heartdisease | restecg, fbs, trestbps)
# (age _|_ chol, restecg | thalach, heartdisease, fbs)
# (age _|_ chol, restecg, heartdisease | thalach, fbs, trestbps)
# (age _|_ thalach, chol, restecg | heartdisease, fbs, trestbps)
# (age _|_ thalach, chol, restecg | heartdisease, fbs, exang)
# (age _|_ thalach, chol, restecg, heartdisease | exang, fbs, trestbps)
# (age _|_ chol | thalach, heartdisease, restecg)
# (age _|_ thalach, chol | heartdisease, restecg, trestbps)
# (age _|_ thalach, chol | heartdisease, restecg, exang)
# (age _|_ chol, restecg | thalach, heartdisease, trestbps)
# (age _|_ chol, restecg | thalach, heartdisease, exang)
# (age _|_ thalach, chol, restecg | heartdisease, exang, trestbps)
# (age _|_ thalach, restecg | chol, sex, fbs, heartdisease)
# (age _|_ thalach, heartdisease, restecg | chol, sex, fbs, trestbps)
# (age _|_ thalach | chol, sex, restecg, heartdisease)
# (age _|_ restecg | thalach, chol, sex, heartdisease)
# (age _|_ thalach, restecg | chol, sex, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, sex, heartdisease, exang)
# (age _|_ thalach | chol, restecg, fbs, heartdisease)
# (age _|_ thalach, heartdisease | chol, restecg, fbs, trestbps)
# (age _|_ restecg | thalach, chol, fbs, heartdisease)
# (age _|_ heartdisease, restecg | thalach, chol, fbs, trestbps)
# (age _|_ thalach, restecg | chol, fbs, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, fbs, heartdisease, exang)
# (age _|_ thalach, heartdisease, restecg | chol, exang, fbs, trestbps)
# (age _|_ thalach | chol, restecg, heartdisease, trestbps)
# (age _|_ thalach | chol, restecg, heartdisease, exang)
# (age _|_ restecg | thalach, chol, heartdisease, trestbps)
# (age _|_ restecg | thalach, chol, heartdisease, exang)
# (age _|_ thalach, restecg | chol, exang, heartdisease, trestbps)
# (age _|_ thalach, chol | heartdisease, restecg, sex, fbs)
# (age _|_ thalach, chol, heartdisease | restecg, sex, fbs, trestbps)
# (age _|_ chol, restecg | thalach, heartdisease, sex, fbs)
# (age _|_ chol, restecg, heartdisease | thalach, sex, fbs, trestbps)
# (age _|_ thalach, chol, restecg | heartdisease, sex, fbs, trestbps)
# (age _|_ thalach, chol, restecg | heartdisease, sex, fbs, exang)
# (age _|_ thalach, chol, restecg, heartdisease | exang, sex, fbs, trestbps)
# (age _|_ chol | thalach, heartdisease, sex, restecg)
# (age _|_ thalach, chol | heartdisease, sex, restecg, trestbps)
# (age _|_ thalach, chol | heartdisease, sex, restecg, exang)
# (age _|_ chol, restecg | thalach, heartdisease, sex, trestbps)
# (age _|_ chol, restecg | thalach, heartdisease, sex, exang)
# (age _|_ thalach, chol, restecg | heartdisease, exang, sex, trestbps)
# (age _|_ chol | thalach, heartdisease, restecg, fbs)
# (age _|_ chol, heartdisease | thalach, restecg, fbs, trestbps)
# (age _|_ thalach, chol | heartdisease, restecg, fbs, trestbps)
# (age _|_ thalach, chol | heartdisease, restecg, fbs, exang)
# (age _|_ thalach, chol, heartdisease | exang, restecg, fbs, trestbps)
# (age _|_ chol, restecg | thalach, heartdisease, fbs, trestbps)
# (age _|_ chol, restecg | thalach, heartdisease, fbs, exang)
# (age _|_ chol, restecg, heartdisease | thalach, exang, fbs, trestbps)
# (age _|_ thalach, chol, restecg | heartdisease, exang, fbs, trestbps)
# (age _|_ chol | thalach, heartdisease, restecg, trestbps)
# (age _|_ chol | thalach, heartdisease, restecg, exang)
# (age _|_ thalach, chol | heartdisease, exang, restecg, trestbps)
# (age _|_ chol, restecg | thalach, heartdisease, exang, trestbps)
# (age _|_ thalach | chol, sex, restecg, fbs, heartdisease)
# (age _|_ thalach, heartdisease | chol, sex, restecg, fbs, trestbps)
# (age _|_ restecg | chol, sex, fbs, thalach, heartdisease)
# (age _|_ heartdisease, restecg | chol, sex, fbs, thalach, trestbps)
# (age _|_ thalach, restecg | chol, sex, fbs, heartdisease, trestbps)
# (age _|_ thalach, restecg | chol, sex, fbs, heartdisease, exang)
# (age _|_ thalach, heartdisease, restecg | chol, sex, fbs, trestbps, exang)
# (age _|_ thalach | chol, sex, restecg, heartdisease, trestbps)
# (age _|_ thalach | chol, sex, restecg, heartdisease, exang)
# (age _|_ restecg | chol, sex, thalach, heartdisease, trestbps)
# (age _|_ restecg | chol, sex, thalach, heartdisease, exang)
# (age _|_ thalach, restecg | chol, sex, heartdisease, trestbps, exang)
# (age _|_ heartdisease | chol, restecg, fbs, thalach, trestbps)
# (age _|_ thalach | chol, restecg, fbs, heartdisease, trestbps)
# (age _|_ thalach | chol, restecg, fbs, heartdisease, exang)
# (age _|_ thalach, heartdisease | chol, restecg, fbs, trestbps, exang)
# (age _|_ restecg | chol, fbs, thalach, heartdisease, trestbps)
# (age _|_ restecg | chol, fbs, thalach, heartdisease, exang)
# (age _|_ heartdisease, restecg | chol, fbs, thalach, trestbps, exang)
# (age _|_ thalach, restecg | chol, fbs, heartdisease, trestbps, exang)
# (age _|_ thalach | chol, restecg, heartdisease, trestbps, exang)
# (age _|_ restecg | chol, thalach, heartdisease, trestbps, exang)
# (age _|_ chol | sex, restecg, fbs, thalach, heartdisease)
# (age _|_ chol, heartdisease | sex, restecg, fbs, thalach, trestbps)
# (age _|_ thalach, chol | sex, restecg, fbs, heartdisease, trestbps)
# (age _|_ thalach, chol | sex, restecg, fbs, heartdisease, exang)
# (age _|_ thalach, chol, heartdisease | sex, restecg, fbs, trestbps, exang)
# (age _|_ chol, restecg | sex, fbs, thalach, heartdisease, trestbps)
# (age _|_ chol, restecg | sex, fbs, thalach, heartdisease, exang)
# (age _|_ chol, restecg, heartdisease | sex, fbs, thalach, trestbps, exang)
# (age _|_ thalach, chol, restecg | sex, fbs, heartdisease, trestbps, exang)
# (age _|_ chol | sex, restecg, thalach, heartdisease, trestbps)
# (age _|_ chol | sex, restecg, thalach, heartdisease, exang)
# (age _|_ thalach, chol | sex, restecg, heartdisease, trestbps, exang)
# (age _|_ chol, restecg | sex, thalach, heartdisease, trestbps, exang)
# (age _|_ chol | restecg, fbs, thalach, heartdisease, trestbps)
# (age _|_ chol | restecg, fbs, thalach, heartdisease, exang)
# (age _|_ chol, heartdisease | restecg, fbs, thalach, trestbps, exang)
# (age _|_ thalach, chol | restecg, fbs, heartdisease, trestbps, exang)
# (age _|_ chol, restecg | fbs, thalach, heartdisease, trestbps, exang)
# (age _|_ chol | restecg, thalach, heartdisease, trestbps, exang)
# (age _|_ heartdisease | chol, sex, restecg, fbs, thalach, trestbps)
# (age _|_ thalach | chol, sex, restecg, fbs, heartdisease, trestbps)
# (age _|_ thalach | chol, sex, restecg, fbs, heartdisease, exang)
# (age _|_ thalach, heartdisease | chol, sex, restecg, fbs, trestbps, exang)
# (age _|_ restecg | chol, sex, fbs, thalach, heartdisease, trestbps)
# (age _|_ restecg | chol, sex, fbs, thalach, heartdisease, exang)
# (age _|_ heartdisease, restecg | chol, sex, fbs, thalach, trestbps, exang)
# (age _|_ thalach, restecg | chol, sex, fbs, heartdisease, trestbps, exang)
# (age _|_ thalach | chol, sex, restecg, heartdisease, trestbps, exang)
# (age _|_ restecg | chol, sex, thalach, heartdisease, trestbps, exang)
# (age _|_ heartdisease | chol, restecg, fbs, thalach, trestbps, exang)
# (age _|_ thalach | chol, restecg, fbs, heartdisease, trestbps, exang)
# (age _|_ restecg | chol, fbs, thalach, heartdisease, trestbps, exang)
# (age _|_ chol | sex, restecg, fbs, thalach, heartdisease, trestbps)
# (age _|_ chol | sex, restecg, fbs, thalach, heartdisease, exang)
# (age _|_ chol, heartdisease | sex, restecg, fbs, thalach, trestbps, exang)
# (age _|_ thalach, chol | sex, restecg, fbs, heartdisease, trestbps, exang)
# (age _|_ chol, restecg | sex, fbs, thalach, heartdisease, trestbps, exang)
# (age _|_ chol | sex, restecg, thalach, heartdisease, trestbps, exang)
# (age _|_ chol | restecg, fbs, thalach, heartdisease, trestbps, exang)
# (age _|_ heartdisease | chol, sex, restecg, fbs, thalach, trestbps, exang)
# (age _|_ thalach | chol, sex, restecg, fbs, heartdisease, trestbps, exang)
# (age _|_ restecg | chol, sex, fbs, thalach, heartdisease, trestbps, exang)
# (age _|_ chol | sex, restecg, fbs, thalach, heartdisease, trestbps, exang)
# (trestbps _|_ fbs | age)
# (trestbps _|_ thalach, chol, restecg | heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease)
# (trestbps _|_ fbs | sex, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex)
# (trestbps _|_ thalach, chol, restecg | heartdisease, fbs)
# (trestbps _|_ thalach, chol | heartdisease, restecg)
# (trestbps _|_ chol, restecg | thalach, heartdisease)
# (trestbps _|_ thalach, chol, restecg | heartdisease, age)
# (trestbps _|_ fbs | exang, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, exang)
# (trestbps _|_ thalach, restecg | chol, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, fbs, heartdisease)
# (trestbps _|_ thalach | chol, restecg, heartdisease)
# (trestbps _|_ restecg | thalach, chol, heartdisease)
# (trestbps _|_ thalach, restecg | chol, heartdisease, age)
# (trestbps _|_ thalach, restecg | chol, heartdisease, exang)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex, fbs)
# (trestbps _|_ thalach, chol | heartdisease, sex, restecg)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex, age)
# (trestbps _|_ fbs | exang, sex, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex, exang)
# (trestbps _|_ thalach, chol | heartdisease, restecg, fbs)
# (trestbps _|_ chol, restecg | thalach, heartdisease, fbs)
# (trestbps _|_ thalach, chol, restecg | heartdisease, fbs, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, fbs, exang)
# (trestbps _|_ chol | thalach, heartdisease, restecg)
# (trestbps _|_ thalach, chol | heartdisease, restecg, age)
# (trestbps _|_ thalach, chol | heartdisease, restecg, exang)
# (trestbps _|_ chol, restecg | thalach, heartdisease, age)
# (trestbps _|_ chol, restecg | thalach, heartdisease, exang)
# (trestbps _|_ thalach, chol, restecg | heartdisease, exang, age)
# (trestbps _|_ thalach, restecg | chol, sex, fbs, heartdisease)
# (trestbps _|_ thalach | chol, sex, restecg, heartdisease)
# (trestbps _|_ restecg | thalach, chol, sex, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, heartdisease, age)
# (trestbps _|_ thalach, restecg | chol, sex, heartdisease, exang)
# (trestbps _|_ thalach | chol, restecg, fbs, heartdisease)
# (trestbps _|_ restecg | thalach, chol, fbs, heartdisease)
# (trestbps _|_ thalach, restecg | chol, fbs, heartdisease, age)
# (trestbps _|_ thalach, restecg | chol, fbs, heartdisease, exang)
# (trestbps _|_ thalach | chol, restecg, heartdisease, age)
# (trestbps _|_ thalach | chol, restecg, heartdisease, exang)
# (trestbps _|_ restecg | thalach, chol, heartdisease, age)
# (trestbps _|_ restecg | thalach, chol, heartdisease, exang)
# (trestbps _|_ thalach, restecg | chol, exang, heartdisease, age)
# (trestbps _|_ thalach, chol | heartdisease, restecg, sex, fbs)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex, fbs)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex, fbs, age)
# (trestbps _|_ thalach, chol, restecg | heartdisease, sex, fbs, exang)
# (trestbps _|_ chol | thalach, heartdisease, sex, restecg)
# (trestbps _|_ thalach, chol | heartdisease, sex, restecg, age)
# (trestbps _|_ thalach, chol | heartdisease, sex, restecg, exang)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex, age)
# (trestbps _|_ chol, restecg | thalach, heartdisease, sex, exang)
# (trestbps _|_ thalach, chol, restecg | heartdisease, exang, sex, age)
# (trestbps _|_ chol | thalach, heartdisease, restecg, fbs)
# (trestbps _|_ thalach, chol | heartdisease, restecg, fbs, age)
# (trestbps _|_ thalach, chol | heartdisease, restecg, fbs, exang)
# (trestbps _|_ chol, restecg | thalach, heartdisease, fbs, age)
# (trestbps _|_ chol, restecg | thalach, heartdisease, fbs, exang)
# (trestbps _|_ thalach, chol, restecg | heartdisease, exang, fbs, age)
# (trestbps _|_ chol | thalach, heartdisease, restecg, age)
# (trestbps _|_ chol | thalach, heartdisease, restecg, exang)
# (trestbps _|_ thalach, chol | heartdisease, exang, restecg, age)
# (trestbps _|_ chol, restecg | thalach, heartdisease, exang, age)
# (trestbps _|_ thalach | chol, sex, restecg, fbs, heartdisease)
# (trestbps _|_ restecg | chol, sex, fbs, thalach, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, fbs, age, heartdisease)
# (trestbps _|_ thalach, restecg | chol, sex, fbs, heartdisease, exang)
# (trestbps _|_ thalach | chol, sex, restecg, age, heartdisease)
# (trestbps _|_ thalach | chol, sex, restecg, heartdisease, exang)
# (trestbps _|_ restecg | chol, sex, thalach, age, heartdisease)
# (trestbps _|_ restecg | chol, sex, thalach, heartdisease, exang)
# (trestbps _|_ thalach, restecg | chol, sex, age, heartdisease, exang)
# (trestbps _|_ thalach | chol, restecg, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, restecg, fbs, heartdisease, exang)
# (trestbps _|_ restecg | chol, fbs, thalach, age, heartdisease)
# (trestbps _|_ restecg | chol, fbs, thalach, heartdisease, exang)
# (trestbps _|_ thalach, restecg | chol, fbs, age, heartdisease, exang)
# (trestbps _|_ thalach | chol, restecg, age, heartdisease, exang)
# (trestbps _|_ restecg | chol, thalach, age, heartdisease, exang)
# (trestbps _|_ chol | sex, restecg, fbs, thalach, heartdisease)
# (trestbps _|_ thalach, chol | sex, restecg, fbs, age, heartdisease)
# (trestbps _|_ thalach, chol | sex, restecg, fbs, heartdisease, exang)
# (trestbps _|_ chol, restecg | sex, fbs, thalach, age, heartdisease)
# (trestbps _|_ chol, restecg | sex, fbs, thalach, heartdisease, exang)
# (trestbps _|_ thalach, chol, restecg | sex, fbs, age, heartdisease, exang)
# (trestbps _|_ chol | sex, restecg, thalach, age, heartdisease)
# (trestbps _|_ chol | sex, restecg, thalach, heartdisease, exang)
# (trestbps _|_ thalach, chol | sex, restecg, age, heartdisease, exang)
# (trestbps _|_ chol, restecg | sex, thalach, age, heartdisease, exang)
# (trestbps _|_ chol | restecg, fbs, thalach, age, heartdisease)
# (trestbps _|_ chol | restecg, fbs, thalach, heartdisease, exang)
# (trestbps _|_ thalach, chol | restecg, fbs, age, heartdisease, exang)
# (trestbps _|_ chol, restecg | fbs, thalach, age, heartdisease, exang)
# (trestbps _|_ chol | restecg, thalach, age, heartdisease, exang)
# (trestbps _|_ thalach | chol, sex, restecg, fbs, age, heartdisease)
# (trestbps _|_ thalach | chol, sex, restecg, fbs, heartdisease, exang)
# (trestbps _|_ restecg | chol, sex, fbs, thalach, age, heartdisease)
# (trestbps _|_ restecg | chol, sex, fbs, thalach, heartdisease, exang)
# (trestbps _|_ thalach, restecg | chol, sex, fbs, age, heartdisease, exang)
# (trestbps _|_ thalach | chol, sex, restecg, age, heartdisease, exang)
# (trestbps _|_ restecg | chol, sex, thalach, age, heartdisease, exang)
# (trestbps _|_ thalach | chol, restecg, fbs, age, heartdisease, exang)
# (trestbps _|_ restecg | chol, fbs, thalach, age, heartdisease, exang)
# (trestbps _|_ chol | sex, restecg, fbs, thalach, age, heartdisease)
# (trestbps _|_ chol | sex, restecg, fbs, thalach, heartdisease, exang)
# (trestbps _|_ thalach, chol | sex, restecg, fbs, age, heartdisease, exang)
# (trestbps _|_ chol, restecg | sex, fbs, thalach, age, heartdisease, exang)
# (trestbps _|_ chol | sex, restecg, thalach, age, heartdisease, exang)
# (trestbps _|_ chol | restecg, fbs, thalach, age, heartdisease, exang)
# (trestbps _|_ thalach | chol, sex, restecg, fbs, age, heartdisease, exang)
# (trestbps _|_ restecg | chol, sex, fbs, thalach, age, heartdisease, exang)
# (trestbps _|_ chol | sex, restecg, fbs, thalach, age, heartdisease, exang)
# (fbs _|_ sex, exang)
# (fbs _|_ exang | sex)
# (fbs _|_ exang, sex, trestbps | age)
# (fbs _|_ thalach, chol, restecg | heartdisease)
# (fbs _|_ sex | exang)
# (fbs _|_ thalach, restecg | chol, heartdisease)
# (fbs _|_ exang, trestbps | sex, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, sex)
# (fbs _|_ thalach, chol | heartdisease, restecg)
# (fbs _|_ chol, restecg | thalach, heartdisease)
# (fbs _|_ thalach, chol, restecg | heartdisease, age)
# (fbs _|_ sex, exang | trestbps, age)
# (fbs _|_ sex, trestbps | exang, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, trestbps)
# (fbs _|_ thalach, chol, restecg | heartdisease, exang)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease)
# (fbs _|_ thalach | chol, restecg, heartdisease)
# (fbs _|_ restecg | thalach, chol, heartdisease)
# (fbs _|_ thalach, restecg | chol, heartdisease, age)
# (fbs _|_ sex, exang | chol, trestbps, age)
# (fbs _|_ thalach, restecg | chol, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | chol, heartdisease, exang)
# (fbs _|_ thalach, chol | heartdisease, sex, restecg)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex)
# (fbs _|_ thalach, chol, restecg | heartdisease, sex, age)
# (fbs _|_ exang | trestbps, sex, age)
# (fbs _|_ trestbps | exang, sex, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, sex, trestbps)
# (fbs _|_ thalach, chol, restecg | heartdisease, sex, exang)
# (fbs _|_ chol | thalach, heartdisease, restecg)
# (fbs _|_ thalach, chol | heartdisease, restecg, age)
# (fbs _|_ sex, exang | trestbps, restecg, age)
# (fbs _|_ thalach, chol | heartdisease, restecg, trestbps)
# (fbs _|_ thalach, chol | heartdisease, restecg, exang)
# (fbs _|_ chol, restecg | thalach, heartdisease, age)
# (fbs _|_ sex, exang | thalach, trestbps, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, trestbps)
# (fbs _|_ chol, restecg | thalach, heartdisease, exang)
# (fbs _|_ chol, sex, restecg, thalach, exang | heartdisease, trestbps, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, exang, age)
# (fbs _|_ sex | exang, trestbps, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, exang, trestbps)
# (fbs _|_ thalach | chol, sex, restecg, heartdisease)
# (fbs _|_ restecg | thalach, chol, sex, heartdisease)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease, age)
# (fbs _|_ exang | chol, trestbps, sex, age)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease, exang)
# (fbs _|_ thalach | chol, restecg, heartdisease, age)
# (fbs _|_ sex, exang | chol, trestbps, restecg, age)
# (fbs _|_ thalach | chol, restecg, heartdisease, trestbps)
# (fbs _|_ thalach | chol, restecg, heartdisease, exang)
# (fbs _|_ restecg | thalach, chol, heartdisease, age)
# (fbs _|_ sex, exang | thalach, chol, trestbps, age)
# (fbs _|_ restecg | thalach, chol, heartdisease, trestbps)
# (fbs _|_ restecg | thalach, chol, heartdisease, exang)
# (fbs _|_ thalach, sex, restecg, exang | chol, trestbps, heartdisease, age)
# (fbs _|_ thalach, restecg | chol, exang, heartdisease, age)
# (fbs _|_ sex | chol, trestbps, exang, age)
# (fbs _|_ thalach, restecg | chol, exang, heartdisease, trestbps)
# (fbs _|_ chol | thalach, heartdisease, sex, restecg)
# (fbs _|_ thalach, chol | heartdisease, sex, restecg, age)
# (fbs _|_ exang | trestbps, sex, restecg, age)
# (fbs _|_ thalach, chol | heartdisease, sex, restecg, trestbps)
# (fbs _|_ thalach, chol | heartdisease, sex, restecg, exang)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex, age)
# (fbs _|_ exang | thalach, trestbps, sex, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex, trestbps)
# (fbs _|_ chol, restecg | thalach, heartdisease, sex, exang)
# (fbs _|_ thalach, chol, restecg, exang | heartdisease, trestbps, sex, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, exang, sex, age)
# (fbs _|_ thalach, chol, restecg | heartdisease, exang, sex, trestbps)
# (fbs _|_ chol | thalach, heartdisease, restecg, age)
# (fbs _|_ sex, exang | thalach, trestbps, restecg, age)
# (fbs _|_ chol | thalach, heartdisease, restecg, trestbps)
# (fbs _|_ chol | thalach, heartdisease, restecg, exang)
# (fbs _|_ thalach, chol, sex, exang | heartdisease, trestbps, restecg, age)
# (fbs _|_ thalach, chol | heartdisease, exang, restecg, age)
# (fbs _|_ sex | exang, trestbps, restecg, age)
# (fbs _|_ thalach, chol | heartdisease, exang, restecg, trestbps)
# (fbs _|_ chol, sex, restecg, exang | thalach, heartdisease, trestbps, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, exang, age)
# (fbs _|_ sex | thalach, exang, trestbps, age)
# (fbs _|_ chol, restecg | thalach, heartdisease, exang, trestbps)
# (fbs _|_ thalach, chol, sex, restecg | heartdisease, trestbps, exang, age)
# (fbs _|_ thalach | chol, sex, restecg, age, heartdisease)
# (fbs _|_ exang | chol, sex, restecg, age, trestbps)
# (fbs _|_ thalach | chol, sex, restecg, heartdisease, trestbps)
# (fbs _|_ thalach | chol, sex, restecg, heartdisease, exang)
# (fbs _|_ restecg | chol, sex, thalach, age, heartdisease)
# (fbs _|_ exang | chol, sex, thalach, age, trestbps)
# (fbs _|_ restecg | chol, sex, thalach, heartdisease, trestbps)
# (fbs _|_ restecg | chol, sex, thalach, heartdisease, exang)
# (fbs _|_ thalach, restecg, exang | chol, sex, age, heartdisease, trestbps)
# (fbs _|_ thalach, restecg | chol, sex, age, heartdisease, exang)
# (fbs _|_ thalach, restecg | chol, sex, heartdisease, trestbps, exang)
# (fbs _|_ sex, exang | chol, restecg, thalach, age, trestbps)
# (fbs _|_ thalach, sex, exang | chol, restecg, age, heartdisease, trestbps)
# (fbs _|_ thalach | chol, restecg, age, heartdisease, exang)
# (fbs _|_ sex | chol, restecg, age, trestbps, exang)
# (fbs _|_ thalach | chol, restecg, heartdisease, trestbps, exang)
# (fbs _|_ sex, restecg, exang | chol, thalach, age, heartdisease, trestbps)
# (fbs _|_ restecg | chol, thalach, age, heartdisease, exang)
# (fbs _|_ sex | chol, thalach, age, trestbps, exang)
# (fbs _|_ restecg | chol, thalach, heartdisease, trestbps, exang)
# (fbs _|_ thalach, sex, restecg | chol, age, heartdisease, trestbps, exang)
# (fbs _|_ chol | sex, restecg, thalach, age, heartdisease)
# (fbs _|_ exang | sex, restecg, thalach, age, trestbps)
# (fbs _|_ chol | sex, restecg, thalach, heartdisease, trestbps)
# (fbs _|_ chol | sex, restecg, thalach, heartdisease, exang)
# (fbs _|_ thalach, chol, exang | sex, restecg, age, heartdisease, trestbps)
# (fbs _|_ thalach, chol | sex, restecg, age, heartdisease, exang)
# (fbs _|_ thalach, chol | sex, restecg, heartdisease, trestbps, exang)
# (fbs _|_ chol, restecg, exang | sex, thalach, age, heartdisease, trestbps)
# (fbs _|_ chol, restecg | sex, thalach, age, heartdisease, exang)
# (fbs _|_ chol, restecg | sex, thalach, heartdisease, trestbps, exang)
# (fbs _|_ thalach, chol, restecg | sex, age, heartdisease, trestbps, exang)
# (fbs _|_ chol, sex, exang | restecg, thalach, age, heartdisease, trestbps)
# (fbs _|_ chol | restecg, thalach, age, heartdisease, exang)
# (fbs _|_ sex | restecg, thalach, age, trestbps, exang)
# (fbs _|_ chol | restecg, thalach, heartdisease, trestbps, exang)
# (fbs _|_ thalach, chol, sex | restecg, age, heartdisease, trestbps, exang)
# (fbs _|_ chol, sex, restecg | thalach, age, heartdisease, trestbps, exang)
# (fbs _|_ exang | chol, sex, restecg, thalach, age, trestbps)
# (fbs _|_ thalach, exang | chol, sex, restecg, age, heartdisease, trestbps)
# (fbs _|_ thalach | chol, sex, restecg, age, heartdisease, exang)
# (fbs _|_ thalach | chol, sex, restecg, heartdisease, trestbps, exang)
# (fbs _|_ restecg, exang | chol, sex, thalach, age, heartdisease, trestbps)
# (fbs _|_ restecg | chol, sex, thalach, age, heartdisease, exang)
# (fbs _|_ restecg | chol, sex, thalach, heartdisease, trestbps, exang)
# (fbs _|_ thalach, restecg | chol, sex, age, heartdisease, trestbps, exang)
# (fbs _|_ sex, exang | chol, restecg, thalach, age, heartdisease, trestbps)
# (fbs _|_ sex | chol, restecg, thalach, age, trestbps, exang)
# (fbs _|_ thalach, sex | chol, restecg, age, heartdisease, trestbps, exang)
# (fbs _|_ sex, restecg | chol, thalach, age, heartdisease, trestbps, exang)
# (fbs _|_ chol, exang | sex, restecg, thalach, age, heartdisease, trestbps)
# (fbs _|_ chol | sex, restecg, thalach, age, heartdisease, exang)
# (fbs _|_ chol | sex, restecg, thalach, heartdisease, trestbps, exang)
# (fbs _|_ thalach, chol | sex, restecg, age, heartdisease, trestbps, exang)
# (fbs _|_ chol, restecg | sex, thalach, age, heartdisease, trestbps, exang)
# (fbs _|_ chol, sex | restecg, thalach, age, heartdisease, trestbps, exang)
# (fbs _|_ exang | chol, sex, restecg, thalach, age, heartdisease, trestbps)
# (fbs _|_ thalach | chol, sex, restecg, age, heartdisease, trestbps, exang)
# (fbs _|_ restecg | chol, sex, thalach, age, heartdisease, trestbps, exang)
# (fbs _|_ sex | chol, restecg, thalach, age, heartdisease, trestbps, exang)
# (fbs _|_ chol | sex, restecg, thalach, age, heartdisease, trestbps, exang)
# (sex _|_ exang, fbs, age)
# (sex _|_ exang, age | fbs)
# (sex _|_ fbs, exang | age)
# (sex _|_ thalach, chol, restecg | heartdisease)
# (sex _|_ fbs, age | exang)
# (sex _|_ thalach, restecg | chol, heartdisease)
# (sex _|_ exang | fbs, age)
# (sex _|_ thalach, chol, restecg | heartdisease, fbs)
# (sex _|_ thalach, chol, restecg, heartdisease | fbs, trestbps)
# (sex _|_ age | fbs, exang)
# (sex _|_ thalach, chol | heartdisease, restecg)
# (sex _|_ chol, restecg | thalach, heartdisease)
# (sex _|_ thalach, chol, restecg | heartdisease, age)
# (sex _|_ chol, heartdisease, fbs, restecg, thalach | trestbps, age)
# (sex _|_ fbs | exang, age)
# (sex _|_ thalach, chol, restecg | heartdisease, trestbps)
# (sex _|_ thalach, chol, restecg | heartdisease, exang)
# (sex _|_ thalach, restecg | chol, fbs, heartdisease)
# (sex _|_ thalach, heartdisease, restecg | chol, fbs, trestbps)
# (sex _|_ thalach | chol, restecg, heartdisease)
# (sex _|_ restecg | thalach, chol, heartdisease)
# (sex _|_ thalach, restecg | chol, heartdisease, age)
# (sex _|_ thalach, heartdisease, fbs, restecg | chol, trestbps, age)
# (sex _|_ thalach, restecg | chol, heartdisease, trestbps)
# (sex _|_ thalach, restecg | chol, heartdisease, exang)
# (sex _|_ thalach, chol | heartdisease, restecg, fbs)
# (sex _|_ thalach, chol, heartdisease | restecg, fbs, trestbps)
# ...
# (thalach _|_ sex, age, exang | chol, restecg, fbs, heartdisease, trestbps)
# (thalach _|_ sex, age, trestbps | chol, restecg, fbs, heartdisease, exang)
# (thalach _|_ sex, age | chol, restecg, fbs, trestbps, exang)
# (thalach _|_ sex, restecg, exang | chol, fbs, age, heartdisease, trestbps)
# (thalach _|_ sex, restecg, trestbps | chol, fbs, age, heartdisease, exang)
# (thalach _|_ sex | chol, fbs, age, trestbps, exang)
# (thalach _|_ sex, restecg, age | chol, fbs, heartdisease, trestbps, exang)
# (thalach _|_ sex, fbs, exang | chol, restecg, age, heartdisease, trestbps)
# (thalach _|_ sex, fbs, trestbps | chol, restecg, age, heartdisease, exang)
# (thalach _|_ sex | chol, restecg, age, trestbps, exang)
# (thalach _|_ sex, fbs, age | chol, restecg, heartdisease, trestbps, exang)
# (thalach _|_ fbs, sex, restecg | chol, age, heartdisease, trestbps, exang)
# (thalach _|_ chol, trestbps, exang | sex, restecg, fbs, age, heartdisease)
# (thalach _|_ exang | sex, restecg, fbs, age, trestbps)
# (thalach _|_ chol, age, exang | sex, restecg, fbs, heartdisease, trestbps)
# (thalach _|_ chol, age, trestbps | sex, restecg, fbs, heartdisease, exang)
# (thalach _|_ age | sex, restecg, fbs, trestbps, exang)
# (thalach _|_ chol, restecg, exang | sex, fbs, age, heartdisease, trestbps)
# (thalach _|_ chol, restecg, trestbps | sex, fbs, age, heartdisease, exang)
# (thalach _|_ chol, restecg, age | sex, fbs, heartdisease, trestbps, exang)
# (thalach _|_ chol, fbs, exang | sex, restecg, age, heartdisease, trestbps)
# (thalach _|_ chol, fbs, trestbps | sex, restecg, age, heartdisease, exang)
# (thalach _|_ chol, fbs, age | sex, restecg, heartdisease, trestbps, exang)
# (thalach _|_ chol, fbs, restecg | sex, age, heartdisease, trestbps, exang)
# (thalach _|_ chol, sex, exang | restecg, fbs, age, heartdisease, trestbps)
# (thalach _|_ chol, sex, trestbps | restecg, fbs, age, heartdisease, exang)
# (thalach _|_ sex | restecg, fbs, age, trestbps, exang)
# (thalach _|_ chol, sex, age | restecg, fbs, heartdisease, trestbps, exang)
# (thalach _|_ chol, sex, restecg | fbs, age, heartdisease, trestbps, exang)
# (thalach _|_ chol, sex, fbs | restecg, age, heartdisease, trestbps, exang)
# (thalach _|_ trestbps, exang | chol, sex, restecg, fbs, age, heartdisease)
# (thalach _|_ exang | chol, sex, restecg, fbs, age, trestbps)
# (thalach _|_ age, exang | chol, sex, restecg, fbs, heartdisease, trestbps)
# (thalach _|_ age, trestbps | chol, sex, restecg, fbs, heartdisease, exang)
# (thalach _|_ age | chol, sex, restecg, fbs, trestbps, exang)
# (thalach _|_ restecg, exang | chol, sex, fbs, age, heartdisease, trestbps)
# (thalach _|_ restecg, trestbps | chol, sex, fbs, age, heartdisease, exang)
# (thalach _|_ restecg, age | chol, sex, fbs, heartdisease, trestbps, exang)
# (thalach _|_ fbs, exang | chol, sex, restecg, age, heartdisease, trestbps)
# (thalach _|_ fbs, trestbps | chol, sex, restecg, age, heartdisease, exang)
# (thalach _|_ fbs, age | chol, sex, restecg, heartdisease, trestbps, exang)
# (thalach _|_ fbs, restecg | chol, sex, age, heartdisease, trestbps, exang)
# (thalach _|_ sex, exang | chol, restecg, fbs, age, heartdisease, trestbps)
# (thalach _|_ sex, trestbps | chol, restecg, fbs, age, heartdisease, exang)
# (thalach _|_ sex | chol, restecg, fbs, age, trestbps, exang)
# (thalach _|_ sex, age | chol, restecg, fbs, heartdisease, trestbps, exang)
# (thalach _|_ sex, restecg | chol, fbs, age, heartdisease, trestbps, exang)
# (thalach _|_ sex, fbs | chol, restecg, age, heartdisease, trestbps, exang)
# (thalach _|_ chol, exang | sex, restecg, fbs, age, heartdisease, trestbps)
# (thalach _|_ chol, trestbps | sex, restecg, fbs, age, heartdisease, exang)
# (thalach _|_ chol, age | sex, restecg, fbs, heartdisease, trestbps, exang)
# (thalach _|_ chol, restecg | sex, fbs, age, heartdisease, trestbps, exang)
# (thalach _|_ chol, fbs | sex, restecg, age, heartdisease, trestbps, exang)
# (thalach _|_ chol, sex | restecg, fbs, age, heartdisease, trestbps, exang)
# (thalach _|_ exang | chol, sex, restecg, fbs, age, heartdisease, trestbps)
# (thalach _|_ trestbps | chol, sex, restecg, fbs, age, heartdisease, exang)
# (thalach _|_ age | chol, sex, restecg, fbs, heartdisease, trestbps, exang)
# (thalach _|_ restecg | chol, sex, fbs, age, heartdisease, trestbps, exang)
# (thalach _|_ fbs | chol, sex, restecg, age, heartdisease, trestbps, exang)
# (thalach _|_ sex | chol, restecg, fbs, age, heartdisease, trestbps, exang)
# (thalach _|_ chol | sex, restecg, fbs, age, heartdisease, trestbps, exang)
# (chol _|_ sex, restecg, fbs, trestbps, thalach, exang, age | heartdisease)
# (chol _|_ fbs, restecg, trestbps, thalach, exang, age | heartdisease, sex)
# (chol _|_ sex, restecg, trestbps, thalach, exang, age | heartdisease, fbs)
# (chol _|_ exang, sex, age | fbs, trestbps)
# (chol _|_ sex, fbs, trestbps, thalach, exang, age | heartdisease, restecg)
# (chol _|_ sex, fbs, restecg, trestbps, exang, age | thalach, heartdisease)
# (chol _|_ sex, fbs, restecg, trestbps, thalach, exang | heartdisease, age)
# (chol _|_ sex, exang | trestbps, age)
# (chol _|_ sex, fbs, restecg, thalach, exang, age | heartdisease, trestbps)
# (chol _|_ sex, fbs, restecg, trestbps, thalach, age | heartdisease, exang)
# (chol _|_ restecg, trestbps, thalach, exang, age | heartdisease, sex, fbs)
# (chol _|_ exang, age | sex, fbs, trestbps)
# (chol _|_ fbs, trestbps, thalach, exang, age | heartdisease, sex, restecg)
# (chol _|_ fbs, restecg, trestbps, exang, age | thalach, heartdisease, sex)
# (chol _|_ fbs, restecg, trestbps, thalach, exang | heartdisease, sex, age)
# (chol _|_ exang | trestbps, sex, age)
# (chol _|_ fbs, restecg, thalach, exang, age | heartdisease, sex, trestbps)
# (chol _|_ fbs, restecg, trestbps, thalach, age | heartdisease, sex, exang)
# (chol _|_ sex, trestbps, thalach, exang, age | heartdisease, restecg, fbs)
# (chol _|_ exang, sex, age | restecg, fbs, trestbps)
# (chol _|_ sex, restecg, trestbps, exang, age | thalach, heartdisease, fbs)
# (chol _|_ exang, sex, age | thalach, fbs, trestbps)
# (chol _|_ sex, restecg, trestbps, thalach, exang | heartdisease, fbs, age)
# (chol _|_ sex, exang | trestbps, fbs, age)
# (chol _|_ sex, restecg, thalach, exang, age | heartdisease, fbs, trestbps)
# (chol _|_ sex, restecg, trestbps, thalach, age | heartdisease, fbs, exang)
# (chol _|_ sex, age | exang, fbs, trestbps)
# (chol _|_ sex, fbs, trestbps, exang, age | thalach, heartdisease, restecg)
# (chol _|_ sex, fbs, trestbps, thalach, exang | heartdisease, restecg, age)
# (chol _|_ sex, exang | trestbps, restecg, age)
# (chol _|_ sex, fbs, thalach, exang, age | heartdisease, restecg, trestbps)
# (chol _|_ sex, fbs, trestbps, thalach, age | heartdisease, restecg, exang)
# (chol _|_ sex, fbs, restecg, trestbps, exang | thalach, heartdisease, age)
# (chol _|_ sex, exang | thalach, trestbps, age)
# (chol _|_ sex, fbs, restecg, exang, age | thalach, heartdisease, trestbps)
# (chol _|_ sex, fbs, restecg, trestbps, age | thalach, heartdisease, exang)
# (chol _|_ sex, fbs, restecg, thalach, exang | heartdisease, trestbps, age)
# (chol _|_ sex, fbs, restecg, trestbps, thalach | heartdisease, exang, age)
# (chol _|_ sex | exang, trestbps, age)
# (chol _|_ sex, fbs, restecg, thalach, age | heartdisease, exang, trestbps)
# (chol _|_ thalach, trestbps, age, exang | heartdisease, restecg, sex, fbs)
# (chol _|_ age, exang | restecg, sex, fbs, trestbps)
# (chol _|_ age, trestbps, restecg, exang | thalach, heartdisease, sex, fbs)
# (chol _|_ age, exang | thalach, sex, fbs, trestbps)
# (chol _|_ thalach, trestbps, restecg, exang | heartdisease, sex, fbs, age)
# (chol _|_ exang | trestbps, sex, fbs, age)
# (chol _|_ thalach, age, restecg, exang | heartdisease, sex, fbs, trestbps)
# (chol _|_ thalach, age, restecg, trestbps | heartdisease, sex, fbs, exang)
# (chol _|_ age | exang, sex, fbs, trestbps)
# (chol _|_ age, trestbps, fbs, exang | thalach, heartdisease, sex, restecg)
# (chol _|_ thalach, trestbps, fbs, exang | heartdisease, sex, restecg, age)
# (chol _|_ exang | trestbps, sex, restecg, age)
# (chol _|_ thalach, age, fbs, exang | heartdisease, sex, restecg, trestbps)
# (chol _|_ thalach, age, fbs, trestbps | heartdisease, sex, restecg, exang)
# (chol _|_ trestbps, fbs, restecg, exang | thalach, heartdisease, sex, age)
# (chol _|_ exang | thalach, trestbps, sex, age)
# (chol _|_ age, fbs, restecg, exang | thalach, heartdisease, sex, trestbps)
# (chol _|_ age, fbs, restecg, trestbps | thalach, heartdisease, sex, exang)
# (chol _|_ thalach, fbs, restecg, exang | heartdisease, trestbps, sex, age)
# (chol _|_ thalach, fbs, restecg, trestbps | heartdisease, exang, sex, age)
# (chol _|_ thalach, fbs, restecg, age | heartdisease, exang, sex, trestbps)
# (chol _|_ trestbps, sex, age, exang | thalach, heartdisease, restecg, fbs)
# (chol _|_ sex, age, exang | thalach, restecg, fbs, trestbps)
# (chol _|_ thalach, trestbps, sex, exang | heartdisease, restecg, fbs, age)
# (chol _|_ sex, exang | trestbps, restecg, fbs, age)
# (chol _|_ thalach, sex, age, exang | heartdisease, restecg, fbs, trestbps)
# (chol _|_ thalach, sex, age, trestbps | heartdisease, restecg, fbs, exang)
# (chol _|_ sex, age | exang, restecg, fbs, trestbps)
# (chol _|_ trestbps, sex, restecg, exang | thalach, heartdisease, fbs, age)
# (chol _|_ sex, exang | thalach, trestbps, fbs, age)
# (chol _|_ age, sex, restecg, exang | thalach, heartdisease, fbs, trestbps)
# (chol _|_ age, sex, restecg, trestbps | thalach, heartdisease, fbs, exang)
# (chol _|_ sex, age | thalach, exang, fbs, trestbps)
# (chol _|_ thalach, sex, restecg, exang | heartdisease, trestbps, fbs, age)
# (chol _|_ thalach, sex, restecg, trestbps | heartdisease, exang, fbs, age)
# (chol _|_ sex | exang, trestbps, fbs, age)
# (chol _|_ thalach, sex, restecg, age | heartdisease, exang, fbs, trestbps)
# (chol _|_ trestbps, sex, fbs, exang | thalach, heartdisease, restecg, age)
# (chol _|_ sex, exang | thalach, trestbps, restecg, age)
# (chol _|_ age, sex, fbs, exang | thalach, heartdisease, restecg, trestbps)
# (chol _|_ age, sex, fbs, trestbps | thalach, heartdisease, restecg, exang)
# (chol _|_ thalach, sex, fbs, exang | heartdisease, trestbps, restecg, age)
# (chol _|_ thalach, sex, fbs, trestbps | heartdisease, exang, restecg, age)
# (chol _|_ sex | exang, trestbps, restecg, age)
# (chol _|_ thalach, sex, fbs, age | heartdisease, exang, restecg, trestbps)
# (chol _|_ fbs, sex, restecg, exang | thalach, heartdisease, trestbps, age)
# (chol _|_ fbs, sex, restecg, trestbps | thalach, heartdisease, exang, age)
# (chol _|_ sex | thalach, exang, trestbps, age)
# (chol _|_ fbs, sex, restecg, age | thalach, heartdisease, exang, trestbps)
# (chol _|_ thalach, fbs, sex, restecg | heartdisease, trestbps, exang, age)
# (chol _|_ trestbps, age, exang | sex, restecg, fbs, thalach, heartdisease)
# (chol _|_ age, exang | sex, restecg, fbs, thalach, trestbps)
# (chol _|_ thalach, trestbps, exang | sex, restecg, fbs, age, heartdisease)
# (chol _|_ exang | sex, restecg, fbs, age, trestbps)
# (chol _|_ thalach, age, exang | sex, restecg, fbs, heartdisease, trestbps)
# (chol _|_ thalach, age, trestbps | sex, restecg, fbs, heartdisease, exang)
# (chol _|_ age | sex, restecg, fbs, trestbps, exang)
# (chol _|_ trestbps, restecg, exang | sex, fbs, thalach, age, heartdisease)
# (chol _|_ exang | sex, fbs, thalach, age, trestbps)
# (chol _|_ age, restecg, exang | sex, fbs, thalach, heartdisease, trestbps)
# (chol _|_ age, restecg, trestbps | sex, fbs, thalach, heartdisease, exang)
# (chol _|_ age | sex, fbs, thalach, trestbps, exang)
# (chol _|_ thalach, restecg, exang | sex, fbs, age, heartdisease, trestbps)
# (chol _|_ thalach, restecg, trestbps | sex, fbs, age, heartdisease, exang)
# (chol _|_ thalach, restecg, age | sex, fbs, heartdisease, trestbps, exang)
# (chol _|_ trestbps, fbs, exang | sex, restecg, thalach, age, heartdisease)
# (chol _|_ exang | sex, restecg, thalach, age, trestbps)
# (chol _|_ age, fbs, exang | sex, restecg, thalach, heartdisease, trestbps)
# (chol _|_ age, fbs, trestbps | sex, restecg, thalach, heartdisease, exang)
# (chol _|_ thalach, fbs, exang | sex, restecg, age, heartdisease, trestbps)
# (chol _|_ thalach, fbs, trestbps | sex, restecg, age, heartdisease, exang)
# (chol _|_ thalach, fbs, age | sex, restecg, heartdisease, trestbps, exang)
# (chol _|_ fbs, restecg, exang | sex, thalach, age, heartdisease, trestbps)
# (chol _|_ fbs, restecg, trestbps | sex, thalach, age, heartdisease, exang)
# (chol _|_ fbs, restecg, age | sex, thalach, heartdisease, trestbps, exang)
# (chol _|_ thalach, fbs, restecg | sex, age, heartdisease, trestbps, exang)
# (chol _|_ trestbps, sex, exang | restecg, fbs, thalach, age, heartdisease)
# (chol _|_ sex, exang | restecg, fbs, thalach, age, trestbps)
# (chol _|_ sex, age, exang | restecg, fbs, thalach, heartdisease, trestbps)
# (chol _|_ sex, age, trestbps | restecg, fbs, thalach, heartdisease, exang)
# (chol _|_ sex, age | restecg, fbs, thalach, trestbps, exang)
# (chol _|_ thalach, sex, exang | restecg, fbs, age, heartdisease, trestbps)
# (chol _|_ thalach, sex, trestbps | restecg, fbs, age, heartdisease, exang)
# (chol _|_ sex | restecg, fbs, age, trestbps, exang)
# (chol _|_ thalach, sex, age | restecg, fbs, heartdisease, trestbps, exang)
# (chol _|_ sex, restecg, exang | fbs, thalach, age, heartdisease, trestbps)
# (chol _|_ sex, restecg, trestbps | fbs, thalach, age, heartdisease, exang)
# (chol _|_ sex | fbs, thalach, age, trestbps, exang)
# (chol _|_ sex, restecg, age | fbs, thalach, heartdisease, trestbps, exang)
# (chol _|_ thalach, sex, restecg | fbs, age, heartdisease, trestbps, exang)
# (chol _|_ sex, fbs, exang | restecg, thalach, age, heartdisease, trestbps)
# (chol _|_ sex, fbs, trestbps | restecg, thalach, age, heartdisease, exang)
# (chol _|_ sex | restecg, thalach, age, trestbps, exang)
# (chol _|_ sex, fbs, age | restecg, thalach, heartdisease, trestbps, exang)
# (chol _|_ thalach, sex, fbs | restecg, age, heartdisease, trestbps, exang)
# (chol _|_ fbs, sex, restecg | thalach, age, heartdisease, trestbps, exang)
# (chol _|_ trestbps, exang | sex, restecg, fbs, thalach, age, heartdisease)
# (chol _|_ exang | sex, restecg, fbs, thalach, age, trestbps)
# (chol _|_ age, exang | sex, restecg, fbs, thalach, heartdisease, trestbps)
# (chol _|_ age, trestbps | sex, restecg, fbs, thalach, heartdisease, exang)
# (chol _|_ age | sex, restecg, fbs, thalach, trestbps, exang)
# (chol _|_ thalach, exang | sex, restecg, fbs, age, heartdisease, trestbps)
# (chol _|_ thalach, trestbps | sex, restecg, fbs, age, heartdisease, exang)
# (chol _|_ thalach, age | sex, restecg, fbs, heartdisease, trestbps, exang)
# (chol _|_ restecg, exang | sex, fbs, thalach, age, heartdisease, trestbps)
# (chol _|_ restecg, trestbps | sex, fbs, thalach, age, heartdisease, exang)
# (chol _|_ restecg, age | sex, fbs, thalach, heartdisease, trestbps, exang)
# (chol _|_ thalach, restecg | sex, fbs, age, heartdisease, trestbps, exang)
# (chol _|_ fbs, exang | sex, restecg, thalach, age, heartdisease, trestbps)
# (chol _|_ fbs, trestbps | sex, restecg, thalach, age, heartdisease, exang)
# (chol _|_ fbs, age | sex, restecg, thalach, heartdisease, trestbps, exang)
# (chol _|_ thalach, fbs | sex, restecg, age, heartdisease, trestbps, exang)
# (chol _|_ fbs, restecg | sex, thalach, age, heartdisease, trestbps, exang)
# (chol _|_ sex, exang | restecg, fbs, thalach, age, heartdisease, trestbps)
# (chol _|_ sex, trestbps | restecg, fbs, thalach, age, heartdisease, exang)
# (chol _|_ sex | restecg, fbs, thalach, age, trestbps, exang)
# (chol _|_ sex, age | restecg, fbs, thalach, heartdisease, trestbps, exang)
# (chol _|_ thalach, sex | restecg, fbs, age, heartdisease, trestbps, exang)
# (chol _|_ sex, restecg | fbs, thalach, age, heartdisease, trestbps, exang)
# (chol _|_ sex, fbs | restecg, thalach, age, heartdisease, trestbps, exang)
# (chol _|_ exang | sex, restecg, fbs, thalach, age, heartdisease, trestbps)
# (chol _|_ trestbps | sex, restecg, fbs, thalach, age, heartdisease, exang)
# (chol _|_ age | sex, restecg, fbs, thalach, heartdisease, trestbps, exang)
# (chol _|_ thalach | sex, restecg, fbs, age, heartdisease, trestbps, exang)
# (chol _|_ restecg | sex, fbs, thalach, age, heartdisease, trestbps, exang)
# (chol _|_ fbs | sex, restecg, thalach, age, heartdisease, trestbps, exang)
# (chol _|_ sex | restecg, fbs, thalach, age, heartdisease, trestbps, exang)

# %%
from pgmpy.inference import VariableElimination
HeartDisease_infer = VariableElimination(model)

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              0.6333 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.3667 │
# ╘════════════════╧═════════════════════╛

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# ╒════════════════╤═════════════════════╕
# │ heartdisease   │   phi(heartdisease) │
# ╞════════════════╪═════════════════════╡
# │ heartdisease_0 │              1.0000 │
# ├────────────────┼─────────────────────┤
# │ heartdisease_1 │              0.0000 │
# ╘════════════════╧═════════════════════╛
