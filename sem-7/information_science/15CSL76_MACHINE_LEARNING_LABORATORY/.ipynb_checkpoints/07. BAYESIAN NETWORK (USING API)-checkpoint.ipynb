# %%
from pgmpy.models import BayesianModel

cancer_model = BayesianModel([('Pollution', 'Cancer'), ('Smoker', 'Cancer'),
                              ('Cancer', 'Xray'), ('Cancer', 'Dyspnoea')])

# %%
print(cancer_model)

# %%
cancer_model.nodes()
# Out:
# NodeView(('Pollution', 'Cancer', 'Smoker', 'Xray', 'Dyspnoea'))

# %%
cancer_model.edges()
# Out:
# OutEdgeView([('Pollution', 'Cancer'), ('Cancer', 'Xray'), ('Cancer', 'Dyspnoea'), ('Smoker', 'Cancer')])

# %%
cancer_model.get_cpds()
# Out:
# []

# %%
from pgmpy.factors.discrete import TabularCPD

cpd_poll = TabularCPD(variable='Pollution',
                      variable_card=2,
                      values=[[0.9], [0.1]])
cpd_smoke = TabularCPD(variable='Smoker',
                       variable_card=2,
                       values=[[0.3], [0.7]])
cpd_cancer = TabularCPD(variable='Cancer',
                        variable_card=2,
                        values=[[0.03, 0.05, 0.001, 0.02],
                                [0.97, 0.95, 0.999, 0.98]],
                        evidence=['Smoker', 'Pollution'],
                        evidence_card=[2, 2])
cpd_xray = TabularCPD(variable='Xray',
                      variable_card=2,
                      values=[[0.9, 0.2], [0.1, 0.8]],
                      evidence=['Cancer'],
                      evidence_card=[2])
cpd_dysp = TabularCPD(variable='Dyspnoea',
                      variable_card=2,
                      values=[[0.65, 0.3], [0.35, 0.7]],
                      evidence=['Cancer'],
                      evidence_card=[2])

# %%
# Associating the parameters with the model structure.
cancer_model.add_cpds(cpd_poll, cpd_smoke, cpd_cancer, cpd_xray, cpd_dysp)
# Checking if the cpds are valid for the model.
cancer_model.check_model()
# Out:
# True

# %%
cancer_model.get_cpds()
# Out:
# [<TabularCPD representing P(Pollution:2) at 0x7f0ebb00c6a0>,
#  <TabularCPD representing P(Smoker:2) at 0x7f0ebb00c668>,
#  <TabularCPD representing P(Cancer:2 | Smoker:2, Pollution:2) at 0x7f0ebb00c630>,
#  <TabularCPD representing P(Xray:2 | Cancer:2) at 0x7f0ebb00c748>,
#  <TabularCPD representing P(Dyspnoea:2 | Cancer:2) at 0x7f0ebb00c780>]

# %%
print(cancer_model.get_cpds('Pollution'))
print(cancer_model.get_cpds('Smoker'))
print(cancer_model.get_cpds('Xray'))
print(cancer_model.get_cpds('Dyspnoea'))
print(cancer_model.get_cpds('Cancer'))
# Out:
# +-------------+-----+
# | Pollution_0 | 0.9 |
# +-------------+-----+
# | Pollution_1 | 0.1 |
# +-------------+-----+
# +----------+-----+
# | Smoker_0 | 0.3 |
# +----------+-----+
# | Smoker_1 | 0.7 |
# +----------+-----+
# +--------+----------+----------+
# | Cancer | Cancer_0 | Cancer_1 |
# +--------+----------+----------+
# | Xray_0 | 0.9      | 0.2      |
# +--------+----------+----------+
# | Xray_1 | 0.1      | 0.8      |
# +--------+----------+----------+
# +------------+----------+----------+
# | Cancer     | Cancer_0 | Cancer_1 |
# +------------+----------+----------+
# | Dyspnoea_0 | 0.65     | 0.3      |
# +------------+----------+----------+
# | Dyspnoea_1 | 0.35     | 0.7      |
# +------------+----------+----------+
# +-----------+-------------+-------------+-------------+-------------+
# | Smoker    | Smoker_0    | Smoker_0    | Smoker_1    | Smoker_1    |
# +-----------+-------------+-------------+-------------+-------------+
# | Pollution | Pollution_0 | Pollution_1 | Pollution_0 | Pollution_1 |
# +-----------+-------------+-------------+-------------+-------------+
# | Cancer_0  | 0.03        | 0.05        | 0.001       | 0.02        |
# +-----------+-------------+-------------+-------------+-------------+
# | Cancer_1  | 0.97        | 0.95        | 0.999       | 0.98        |
# +-----------+-------------+-------------+-------------+-------------+

# %%
cancer_model.local_independencies('Xray')
cancer_model.local_independencies('Pollution')
cancer_model.local_independencies('Smoker')
cancer_model.local_independencies('Dyspnoea')
cancer_model.local_independencies('Cancer')
# Out:
# (Cancer _|_ Xray, Dyspnoea | Smoker, Pollution)

# %%
cancer_model.get_independencies()
# Out:
# (Pollution _|_ Smoker)
# (Pollution _|_ Xray, Dyspnoea | Cancer)
# (Pollution _|_ Xray, Dyspnoea | Cancer, Smoker)
# (Pollution _|_ Dyspnoea | Cancer, Xray)
# (Pollution _|_ Xray | Cancer, Dyspnoea)
# (Pollution _|_ Dyspnoea | Cancer, Smoker, Xray)
# (Pollution _|_ Xray | Cancer, Smoker, Dyspnoea)
# (Smoker _|_ Pollution)
# (Smoker _|_ Xray, Dyspnoea | Cancer)
# (Smoker _|_ Xray, Dyspnoea | Cancer, Pollution)
# (Smoker _|_ Dyspnoea | Cancer, Xray)
# (Smoker _|_ Xray | Cancer, Dyspnoea)
# (Smoker _|_ Dyspnoea | Cancer, Xray, Pollution)
# (Smoker _|_ Xray | Cancer, Pollution, Dyspnoea)
# (Xray _|_ Smoker, Pollution, Dyspnoea | Cancer)
# (Xray _|_ Pollution, Dyspnoea | Cancer, Smoker)
# (Xray _|_ Smoker, Dyspnoea | Cancer, Pollution)
# (Xray _|_ Smoker, Pollution | Cancer, Dyspnoea)
# (Xray _|_ Dyspnoea | Cancer, Smoker, Pollution)
# (Xray _|_ Pollution | Cancer, Smoker, Dyspnoea)
# (Xray _|_ Smoker | Cancer, Pollution, Dyspnoea)
# (Dyspnoea _|_ Smoker, Pollution, Xray | Cancer)
# (Dyspnoea _|_ Pollution, Xray | Cancer, Smoker)
# (Dyspnoea _|_ Smoker, Xray | Cancer, Pollution)
# (Dyspnoea _|_ Smoker, Pollution | Cancer, Xray)
# (Dyspnoea _|_ Xray | Cancer, Smoker, Pollution)
# (Dyspnoea _|_ Pollution | Cancer, Smoker, Xray)
# (Dyspnoea _|_ Smoker | Cancer, Xray, Pollution)

# %%
# Doing exact inference using Variable Elimination
from pgmpy.inference import VariableElimination

cancer_infer = VariableElimination(cancer_model)

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'], evidence={'Smoker': 1})
print(q['Cancer'])
# Out:
# +----------+---------------+
# | Cancer   |   phi(Cancer) |
# +==========+===============+
# | Cancer_0 |        0.0029 |
# +----------+---------------+
# | Cancer_1 |        0.9971 |
# +----------+---------------+
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:598: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi1.values = phi1.values[slice_]

# %%
# Computing the probability of bronc given smoke.
q = cancer_infer.query(variables=['Cancer'],
                       evidence={
                           'Smoker': 1,
                           'Pollution': 1
                       })
print(q['Cancer'])
# Out:
# +----------+---------------+
# | Cancer   |   phi(Cancer) |
# +==========+===============+
# | Cancer_0 |        0.0200 |
# +----------+---------------+
# | Cancer_1 |        0.9800 |
# +----------+---------------+

# %%
import sys
import urllib
from urllib.request import urlopen

import matplotlib.pyplot as plt  # Visuals
import numpy as np
import pandas as pd
import seaborn as sns
import sklearn as skl

# %%
Cleveland_data_URL = 'http://archive.ics.uci.edu/ml/machine-learning-databases/heart-disease/processed.hungarian.data'
np.set_printoptions(
    threshold=sys.maxsize)  #see a whole array when we output it
names = [
    'age', 'sex', 'cp', 'trestbps', 'chol', 'fbs', 'restecg', 'thalach',
    'exang', 'oldpeak', 'slope', 'ca', 'thal', 'heartdisease'
]
heartDisease = pd.read_csv(urlopen(Cleveland_data_URL),
                           names=names)  #gets Cleveland data

# %%
del heartDisease['ca']
del heartDisease['slope']
del heartDisease['thal']
del heartDisease['oldpeak']

heartDisease = heartDisease.replace('?', np.nan)

# %%
from pgmpy.estimators import BayesianEstimator, MaximumLikelihoodEstimator
from pgmpy.models import BayesianModel

model = BayesianModel([('age', 'trestbps'), ('age', 'fbs'),
                       ('sex', 'trestbps'), ('sex', 'trestbps'),
                       ('exang', 'trestbps'), ('trestbps', 'heartdisease'),
                       ('fbs', 'heartdisease'), ('heartdisease', 'restecg'),
                       ('heartdisease', 'thalach'), ('heartdisease', 'chol')])

# Learing CPDs using Maximum Likelihood Estimators
model.fit(heartDisease, estimator=MaximumLikelihoodEstimator)
#for cpd in model.get_cpds():
#   print("CPD of {variable}:".format(variable=cpd.variable))
#  print(cpd)
# Out:
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/estimators/base.py:54: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   states = sorted(list(self.data.ix[:, variable].dropna().unique()))
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/estimators/base.py:116: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   state_count_data = data.ix[:, variable].value_counts()
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/estimators/MLE.py:128: FutureWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#ix-indexer-is-deprecated
#   state_counts.ix[:, (state_counts == 0).all()] = 1

# %%
print(model.get_cpds('age'))
print(model.get_cpds('chol'))
print(model.get_cpds('sex'))
model.get_independencies()
# Out:
# +---------+------------+
# | age(28) | 0.00383142 |
# +---------+------------+
# | age(29) | 0.00383142 |
# +---------+------------+
# | age(30) | 0.00383142 |
# +---------+------------+
# | age(31) | 0.00766284 |
# +---------+------------+
# | age(32) | 0.0153257  |
# +---------+------------+
# | age(33) | 0.00766284 |
# +---------+------------+
# | age(34) | 0.0153257  |
# +---------+------------+
# | age(35) | 0.0191571  |
# +---------+------------+
# | age(36) | 0.0191571  |
# +---------+------------+
# | age(37) | 0.0306513  |
# +---------+------------+
# | age(38) | 0.0191571  |
# +---------+------------+
# | age(39) | 0.0344828  |
# +---------+------------+
# | age(40) | 0.0191571  |
# +---------+------------+
# | age(41) | 0.0383142  |
# +---------+------------+
# | age(42) | 0.0268199  |
# +---------+------------+
# | age(43) | 0.0421456  |
# +---------+------------+
# | age(44) | 0.0268199  |
# +---------+------------+
# | age(45) | 0.0229885  |
# +---------+------------+
# | age(46) | 0.045977   |
# +---------+------------+
# | age(47) | 0.0344828  |
# +---------+------------+
# | age(48) | 0.0613027  |
# +---------+------------+
# | age(49) | 0.0421456  |
# +---------+------------+
# | age(50) | 0.045977   |
# +---------+------------+
# | age(51) | 0.0344828  |
# +---------+------------+
# | age(52) | 0.0574713  |
# +---------+------------+
# | age(53) | 0.0383142  |
# +---------+------------+
# | age(54) | 0.0842912  |
# +---------+------------+
# | age(55) | 0.0536398  |
# +---------+------------+
# | age(56) | 0.0306513  |
# +---------+------------+
# | age(57) | 0.0191571  |
# +---------+------------+
# | age(58) | 0.0344828  |
# +---------+------------+
# | age(59) | 0.0229885  |
# +---------+------------+
# | age(60) | 0.00766284 |
# +---------+------------+
# | age(61) | 0.00766284 |
# +---------+------------+
# | age(62) | 0.00766284 |
# +---------+------------+
# | age(63) | 0.00383142 |
# +---------+------------+
# | age(65) | 0.0114943  |
# +---------+------------+
# | age(66) | 0          |
# +---------+------------+
# +--------------+----------------------+----------------------+
# | heartdisease | heartdisease(0)      | heartdisease(1)      |
# +--------------+----------------------+----------------------+
# | chol(100)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(117)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(129)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(132)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(147)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(156)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(160)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(161)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(163)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(164)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(166)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(167)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(168)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(171)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(172)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(173)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(175)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(179)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(180)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(182)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(184)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(186)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(187)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(188)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(190)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(193)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(194)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(195)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(196)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(198)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(200)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(201)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(202)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(204)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(205)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(206)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(207)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(208)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(209)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(210)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(211)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(212)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(213)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(214)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(215)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(216)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(217)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(218)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(219)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(220)    | 0.018404907975460124 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(221)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(222)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(223)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(224)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(225)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(226)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(227)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(228)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(229)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(230)    | 0.024539877300613498 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(231)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(233)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(234)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(237)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(238)    | 0.024539877300613498 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(240)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(241)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(242)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(243)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(245)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(246)    | 0.012269938650306749 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(247)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(248)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(249)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(250)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(251)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(253)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(254)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(255)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(256)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(257)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(259)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(260)    | 0.018404907975460124 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(263)    | 0.006134969325153374 | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(264)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(265)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(266)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(267)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(268)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(269)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(270)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(271)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(272)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(273)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(274)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(275)    | 0.012269938650306749 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(276)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(277)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(279)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(280)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(281)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(282)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(283)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(284)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(285)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(287)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(288)    | 0.0                  | 0.030612244897959183 |
# +--------------+----------------------+----------------------+
# | chol(289)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(290)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(291)    | 0.006134969325153374 | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(292)    | 0.012269938650306749 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(294)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(295)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(297)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(298)    | 0.006134969325153374 | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(303)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(305)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(306)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(307)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(308)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(309)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(312)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(315)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(318)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(320)    | 0.012269938650306749 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(326)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(328)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(329)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(331)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(336)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(338)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(339)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(340)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(341)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(342)    | 0.0                  | 0.02040816326530612  |
# +--------------+----------------------+----------------------+
# | chol(344)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(347)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(355)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(358)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(365)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(388)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(392)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(393)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(394)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(404)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(412)    | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(466)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(468)    | 0.0                  | 0.0                  |
# +--------------+----------------------+----------------------+
# | chol(491)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(518)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(529)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(603)    | 0.0                  | 0.01020408163265306  |
# +--------------+----------------------+----------------------+
# | chol(85)     | 0.006134969325153374 | 0.0                  |
# +--------------+----------------------+----------------------+
# +--------+----------+
# | sex(0) | 0.264368 |
# +--------+----------+
# | sex(1) | 0.735632 |
# +--------+----------+
# (age _|_ sex, exang)
# (age _|_ sex, exang | fbs)
# (age _|_ sex | exang)
# (age _|_ exang | sex)
# (age _|_ restecg, chol, thalach | heartdisease)
# (age _|_ sex | exang, fbs)
# (age _|_ exang | sex, fbs)
# (age _|_ restecg, chol, heartdisease, thalach | trestbps, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, fbs)
# (age _|_ restecg, chol | heartdisease, thalach)
# (age _|_ chol, thalach | restecg, heartdisease)
# (age _|_ restecg, chol, thalach | exang, heartdisease)
# (age _|_ restecg, thalach | chol, heartdisease)
# (age _|_ restecg, chol, thalach | sex, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, heartdisease)
# (age _|_ restecg, chol, heartdisease | trestbps, fbs, thalach)
# (age _|_ restecg, chol | heartdisease, fbs, thalach)
# (age _|_ chol, heartdisease, thalach | restecg, trestbps, fbs)
# (age _|_ chol, thalach | restecg, heartdisease, fbs)
# (age _|_ restecg, chol, heartdisease, thalach | trestbps, exang, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, exang, fbs)
# (age _|_ restecg, heartdisease, thalach | trestbps, chol, fbs)
# (age _|_ restecg, thalach | heartdisease, chol, fbs)
# (age _|_ restecg, chol, heartdisease, thalach | sex, trestbps, fbs)
# (age _|_ restecg, chol, thalach | sex, heartdisease, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps, fbs)
# (age _|_ chol | restecg, heartdisease, thalach)
# (age _|_ restecg, chol | exang, heartdisease, thalach)
# (age _|_ restecg | chol, heartdisease, thalach)
# (age _|_ restecg, chol | sex, heartdisease, thalach)
# (age _|_ restecg, chol | trestbps, heartdisease, thalach)
# (age _|_ chol, thalach | restecg, exang, heartdisease)
# (age _|_ thalach | restecg, chol, heartdisease)
# (age _|_ chol, thalach | restecg, sex, heartdisease)
# (age _|_ chol, thalach | restecg, trestbps, heartdisease)
# (age _|_ restecg, thalach | chol, exang, heartdisease)
# (age _|_ restecg, chol, thalach | sex, exang, heartdisease)
# (age _|_ restecg, chol, thalach | trestbps, exang, heartdisease)
# (age _|_ restecg, thalach | sex, chol, heartdisease)
# (age _|_ restecg, thalach | trestbps, chol, heartdisease)
# (age _|_ restecg, chol, thalach | sex, trestbps, heartdisease)
# (age _|_ chol, heartdisease | restecg, trestbps, fbs, thalach)
# (age _|_ chol | restecg, heartdisease, fbs, thalach)
# (age _|_ restecg, chol, heartdisease | trestbps, exang, fbs, thalach)
# (age _|_ restecg, chol | heartdisease, exang, fbs, thalach)
# (age _|_ restecg, heartdisease | trestbps, chol, fbs, thalach)
# (age _|_ restecg | heartdisease, chol, fbs, thalach)
# (age _|_ restecg, chol, heartdisease | sex, trestbps, fbs, thalach)
# (age _|_ restecg, chol | sex, heartdisease, fbs, thalach)
# (age _|_ restecg, chol | heartdisease, trestbps, fbs, thalach)
# (age _|_ chol, heartdisease, thalach | restecg, trestbps, exang, fbs)
# (age _|_ chol, thalach | restecg, heartdisease, exang, fbs)
# (age _|_ heartdisease, thalach | restecg, trestbps, chol, fbs)
# (age _|_ thalach | restecg, heartdisease, chol, fbs)
# (age _|_ chol, heartdisease, thalach | restecg, sex, trestbps, fbs)
# (age _|_ chol, thalach | restecg, sex, heartdisease, fbs)
# (age _|_ chol, thalach | restecg, heartdisease, trestbps, fbs)
# (age _|_ restecg, heartdisease, thalach | trestbps, chol, exang, fbs)
# (age _|_ restecg, thalach | heartdisease, chol, exang, fbs)
# (age _|_ restecg, chol, heartdisease, thalach | sex, trestbps, exang, fbs)
# (age _|_ restecg, chol, thalach | sex, heartdisease, exang, fbs)
# (age _|_ restecg, chol, thalach | heartdisease, trestbps, exang, fbs)
# (age _|_ restecg, heartdisease, thalach | sex, trestbps, chol, fbs)
# (age _|_ restecg, thalach | sex, heartdisease, chol, fbs)
# (age _|_ restecg, thalach | heartdisease, trestbps, chol, fbs)
# (age _|_ restecg, chol, thalach | sex, heartdisease, trestbps, fbs)
# (age _|_ chol | restecg, exang, heartdisease, thalach)
# (age _|_ chol | restecg, sex, heartdisease, thalach)
# (age _|_ chol | restecg, trestbps, heartdisease, thalach)
# (age _|_ restecg | chol, exang, heartdisease, thalach)
# (age _|_ restecg, chol | sex, exang, heartdisease, thalach)
# (age _|_ restecg, chol | trestbps, exang, heartdisease, thalach)
# (age _|_ restecg | sex, chol, heartdisease, thalach)
# (age _|_ restecg | trestbps, chol, heartdisease, thalach)
# (age _|_ restecg, chol | sex, trestbps, heartdisease, thalach)
# (age _|_ thalach | restecg, chol, exang, heartdisease)
# (age _|_ chol, thalach | restecg, sex, exang, heartdisease)
# (age _|_ chol, thalach | restecg, trestbps, exang, heartdisease)
# (age _|_ thalach | restecg, sex, chol, heartdisease)
# (age _|_ thalach | restecg, trestbps, chol, heartdisease)
# (age _|_ chol, thalach | restecg, sex, trestbps, heartdisease)
# (age _|_ restecg, thalach | sex, chol, exang, heartdisease)
# (age _|_ restecg, thalach | trestbps, chol, exang, heartdisease)
# (age _|_ restecg, chol, thalach | sex, trestbps, exang, heartdisease)
# (age _|_ restecg, thalach | sex, trestbps, chol, heartdisease)
# (age _|_ chol, heartdisease | fbs, thalach, restecg, exang, trestbps)
# (age _|_ chol | fbs, thalach, restecg, exang, heartdisease)
# (age _|_ heartdisease | fbs, thalach, restecg, chol, trestbps)
# (age _|_ chol, heartdisease | fbs, thalach, restecg, sex, trestbps)
# (age _|_ chol | fbs, thalach, restecg, sex, heartdisease)
# (age _|_ chol | fbs, thalach, restecg, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | fbs, thalach, exang, chol, trestbps)
# (age _|_ restecg | fbs, thalach, exang, chol, heartdisease)
# (age _|_ restecg, chol, heartdisease | fbs, thalach, exang, sex, trestbps)
# (age _|_ restecg, chol | fbs, thalach, exang, sex, heartdisease)
# (age _|_ restecg, chol | fbs, thalach, exang, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | fbs, thalach, chol, sex, trestbps)
# (age _|_ restecg | fbs, thalach, chol, sex, heartdisease)
# (age _|_ restecg | fbs, thalach, chol, trestbps, heartdisease)
# (age _|_ restecg, chol | fbs, thalach, sex, trestbps, heartdisease)
# (age _|_ heartdisease, thalach | fbs, restecg, exang, chol, trestbps)
# (age _|_ thalach | fbs, restecg, exang, chol, heartdisease)
# (age _|_ chol, heartdisease, thalach | fbs, restecg, exang, sex, trestbps)
# (age _|_ chol, thalach | fbs, restecg, exang, sex, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, exang, trestbps, heartdisease)
# (age _|_ heartdisease, thalach | fbs, restecg, chol, sex, trestbps)
# (age _|_ thalach | fbs, restecg, chol, sex, heartdisease)
# (age _|_ thalach | fbs, restecg, chol, trestbps, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, sex, trestbps, heartdisease)
# (age _|_ restecg, heartdisease, thalach | fbs, exang, chol, sex, trestbps)
# (age _|_ restecg, thalach | fbs, exang, chol, sex, heartdisease)
# (age _|_ restecg, thalach | fbs, exang, chol, trestbps, heartdisease)
# (age _|_ restecg, chol, thalach | fbs, exang, sex, trestbps, heartdisease)
# (age _|_ restecg, thalach | fbs, chol, sex, trestbps, heartdisease)
# (age _|_ chol | thalach, restecg, exang, sex, heartdisease)
# (age _|_ chol | thalach, restecg, exang, trestbps, heartdisease)
# (age _|_ chol | thalach, restecg, sex, trestbps, heartdisease)
# (age _|_ restecg | thalach, exang, chol, sex, heartdisease)
# (age _|_ restecg | thalach, exang, chol, trestbps, heartdisease)
# (age _|_ restecg, chol | thalach, exang, sex, trestbps, heartdisease)
# (age _|_ restecg | thalach, chol, sex, trestbps, heartdisease)
# (age _|_ thalach | restecg, exang, chol, sex, heartdisease)
# (age _|_ thalach | restecg, exang, chol, trestbps, heartdisease)
# (age _|_ chol, thalach | restecg, exang, sex, trestbps, heartdisease)
# (age _|_ thalach | restecg, chol, sex, trestbps, heartdisease)
# (age _|_ restecg, thalach | exang, chol, sex, trestbps, heartdisease)
# (age _|_ heartdisease | fbs, thalach, restecg, exang, chol, trestbps)
# (age _|_ chol, heartdisease | fbs, thalach, restecg, exang, sex, trestbps)
# (age _|_ chol | fbs, thalach, restecg, exang, sex, heartdisease)
# (age _|_ chol | fbs, thalach, restecg, exang, trestbps, heartdisease)
# (age _|_ heartdisease | fbs, thalach, restecg, chol, sex, trestbps)
# (age _|_ chol | fbs, thalach, restecg, sex, trestbps, heartdisease)
# (age _|_ restecg, heartdisease | fbs, thalach, exang, chol, sex, trestbps)
# (age _|_ restecg | fbs, thalach, exang, chol, sex, heartdisease)
# (age _|_ restecg | fbs, thalach, exang, chol, trestbps, heartdisease)
# (age _|_ restecg, chol | fbs, thalach, exang, sex, trestbps, heartdisease)
# (age _|_ restecg | fbs, thalach, chol, sex, trestbps, heartdisease)
# (age _|_ heartdisease, thalach | fbs, restecg, exang, chol, sex, trestbps)
# (age _|_ thalach | fbs, restecg, exang, chol, sex, heartdisease)
# (age _|_ thalach | fbs, restecg, exang, chol, trestbps, heartdisease)
# (age _|_ chol, thalach | fbs, restecg, exang, sex, trestbps, heartdisease)
# (age _|_ thalach | fbs, restecg, chol, sex, trestbps, heartdisease)
# (age _|_ restecg, thalach | fbs, exang, chol, sex, trestbps, heartdisease)
# (age _|_ chol | thalach, restecg, exang, sex, trestbps, heartdisease)
# (age _|_ restecg | thalach, exang, chol, sex, trestbps, heartdisease)
# (age _|_ thalach | restecg, exang, chol, sex, trestbps, heartdisease)
# (age _|_ heartdisease | fbs, thalach, restecg, exang, chol, sex, trestbps)
# (age _|_ chol | fbs, thalach, restecg, exang, sex, trestbps, heartdisease)
# (age _|_ restecg | fbs, thalach, exang, chol, sex, trestbps, heartdisease)
# (age _|_ thalach | fbs, restecg, exang, chol, sex, trestbps, heartdisease)
# (trestbps _|_ fbs | age)
# (trestbps _|_ restecg, chol, thalach | heartdisease)
# (trestbps _|_ fbs | age, exang)
# (trestbps _|_ fbs | age, sex)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease)
# (trestbps _|_ restecg, chol, thalach | heartdisease, fbs)
# (trestbps _|_ restecg, chol | heartdisease, thalach)
# (trestbps _|_ chol, thalach | restecg, heartdisease)
# (trestbps _|_ restecg, chol, thalach | exang, heartdisease)
# (trestbps _|_ restecg, thalach | chol, heartdisease)
# (trestbps _|_ restecg, chol, thalach | sex, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease, fbs)
# (trestbps _|_ restecg, chol | age, heartdisease, thalach)
# (trestbps _|_ chol, thalach | age, restecg, heartdisease)
# (trestbps _|_ fbs | age, sex, exang)
# (trestbps _|_ restecg, chol, thalach | age, exang, heartdisease)
# (trestbps _|_ restecg, thalach | age, chol, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, sex, heartdisease)
# (trestbps _|_ restecg, chol | heartdisease, fbs, thalach)
# (trestbps _|_ chol, thalach | restecg, heartdisease, fbs)
# (trestbps _|_ restecg, chol, thalach | heartdisease, exang, fbs)
# (trestbps _|_ restecg, thalach | heartdisease, chol, fbs)
# (trestbps _|_ restecg, chol, thalach | sex, heartdisease, fbs)
# (trestbps _|_ chol | restecg, heartdisease, thalach)
# (trestbps _|_ restecg, chol | exang, heartdisease, thalach)
# (trestbps _|_ restecg | chol, heartdisease, thalach)
# (trestbps _|_ restecg, chol | sex, heartdisease, thalach)
# (trestbps _|_ chol, thalach | restecg, exang, heartdisease)
# (trestbps _|_ thalach | restecg, chol, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, heartdisease)
# (trestbps _|_ restecg, thalach | chol, exang, heartdisease)
# (trestbps _|_ restecg, chol, thalach | sex, exang, heartdisease)
# (trestbps _|_ restecg, thalach | sex, chol, heartdisease)
# (trestbps _|_ restecg, chol | age, heartdisease, fbs, thalach)
# (trestbps _|_ chol, thalach | age, heartdisease, restecg, fbs)
# (trestbps _|_ restecg, chol, thalach | age, heartdisease, exang, fbs)
# (trestbps _|_ restecg, thalach | age, heartdisease, chol, fbs)
# (trestbps _|_ restecg, chol, thalach | age, sex, heartdisease, fbs)
# (trestbps _|_ chol | age, restecg, heartdisease, thalach)
# (trestbps _|_ restecg, chol | age, exang, heartdisease, thalach)
# (trestbps _|_ restecg | age, chol, heartdisease, thalach)
# (trestbps _|_ restecg, chol | age, sex, heartdisease, thalach)
# (trestbps _|_ chol, thalach | age, restecg, exang, heartdisease)
# (trestbps _|_ thalach | age, heartdisease, restecg, chol)
# (trestbps _|_ chol, thalach | age, sex, restecg, heartdisease)
# (trestbps _|_ restecg, thalach | age, chol, exang, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, sex, exang, heartdisease)
# (trestbps _|_ restecg, thalach | age, sex, chol, heartdisease)
# (trestbps _|_ chol | restecg, heartdisease, fbs, thalach)
# (trestbps _|_ restecg, chol | heartdisease, exang, fbs, thalach)
# (trestbps _|_ restecg | heartdisease, chol, fbs, thalach)
# (trestbps _|_ restecg, chol | sex, heartdisease, fbs, thalach)
# (trestbps _|_ chol, thalach | restecg, heartdisease, exang, fbs)
# (trestbps _|_ thalach | restecg, heartdisease, chol, fbs)
# (trestbps _|_ chol, thalach | restecg, sex, heartdisease, fbs)
# (trestbps _|_ restecg, thalach | heartdisease, chol, exang, fbs)
# (trestbps _|_ restecg, chol, thalach | sex, heartdisease, exang, fbs)
# (trestbps _|_ restecg, thalach | sex, heartdisease, chol, fbs)
# (trestbps _|_ chol | restecg, exang, heartdisease, thalach)
# (trestbps _|_ chol | restecg, sex, heartdisease, thalach)
# (trestbps _|_ restecg | chol, exang, heartdisease, thalach)
# (trestbps _|_ restecg, chol | sex, exang, heartdisease, thalach)
# (trestbps _|_ restecg | sex, chol, heartdisease, thalach)
# (trestbps _|_ thalach | restecg, chol, exang, heartdisease)
# (trestbps _|_ chol, thalach | restecg, sex, exang, heartdisease)
# (trestbps _|_ thalach | restecg, sex, chol, heartdisease)
# (trestbps _|_ restecg, thalach | sex, chol, exang, heartdisease)
# (trestbps _|_ chol | age, fbs, thalach, restecg, heartdisease)
# (trestbps _|_ restecg, chol | age, fbs, thalach, exang, heartdisease)
# (trestbps _|_ restecg | age, fbs, thalach, chol, heartdisease)
# (trestbps _|_ restecg, chol | age, fbs, thalach, sex, heartdisease)
# (trestbps _|_ chol, thalach | age, fbs, restecg, exang, heartdisease)
# (trestbps _|_ thalach | age, fbs, restecg, chol, heartdisease)
# (trestbps _|_ chol, thalach | age, fbs, restecg, sex, heartdisease)
# (trestbps _|_ restecg, thalach | age, fbs, exang, chol, heartdisease)
# (trestbps _|_ restecg, chol, thalach | age, fbs, exang, sex, heartdisease)
# (trestbps _|_ restecg, thalach | age, fbs, chol, sex, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, exang, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | age, thalach, exang, chol, heartdisease)
# (trestbps _|_ restecg, chol | age, thalach, exang, sex, heartdisease)
# (trestbps _|_ restecg | age, thalach, chol, sex, heartdisease)
# (trestbps _|_ thalach | age, restecg, exang, chol, heartdisease)
# (trestbps _|_ chol, thalach | age, restecg, exang, sex, heartdisease)
# (trestbps _|_ thalach | age, restecg, chol, sex, heartdisease)
# (trestbps _|_ restecg, thalach | age, exang, chol, sex, heartdisease)
# (trestbps _|_ chol | fbs, thalach, restecg, exang, heartdisease)
# (trestbps _|_ chol | fbs, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | fbs, thalach, exang, chol, heartdisease)
# (trestbps _|_ restecg, chol | fbs, thalach, exang, sex, heartdisease)
# (trestbps _|_ restecg | fbs, thalach, chol, sex, heartdisease)
# (trestbps _|_ thalach | fbs, restecg, exang, chol, heartdisease)
# (trestbps _|_ chol, thalach | fbs, restecg, exang, sex, heartdisease)
# (trestbps _|_ thalach | fbs, restecg, chol, sex, heartdisease)
# (trestbps _|_ restecg, thalach | fbs, exang, chol, sex, heartdisease)
# (trestbps _|_ chol | thalach, restecg, exang, sex, heartdisease)
# (trestbps _|_ restecg | thalach, exang, chol, sex, heartdisease)
# (trestbps _|_ thalach | restecg, exang, chol, sex, heartdisease)
# (trestbps _|_ chol | age, fbs, thalach, restecg, exang, heartdisease)
# (trestbps _|_ chol | age, fbs, thalach, restecg, sex, heartdisease)
# (trestbps _|_ restecg | age, fbs, thalach, exang, chol, heartdisease)
# (trestbps _|_ restecg, chol | age, fbs, thalach, exang, sex, heartdisease)
# (trestbps _|_ restecg | age, fbs, thalach, chol, sex, heartdisease)
# (trestbps _|_ thalach | age, fbs, restecg, exang, chol, heartdisease)
# (trestbps _|_ chol, thalach | age, fbs, restecg, exang, sex, heartdisease)
# (trestbps _|_ thalach | age, fbs, restecg, chol, sex, heartdisease)
# (trestbps _|_ restecg, thalach | age, fbs, exang, chol, sex, heartdisease)
# (trestbps _|_ chol | age, thalach, restecg, exang, sex, heartdisease)
# (trestbps _|_ restecg | age, thalach, exang, chol, sex, heartdisease)
# (trestbps _|_ thalach | age, restecg, exang, chol, sex, heartdisease)
# (trestbps _|_ chol | fbs, thalach, restecg, exang, sex, heartdisease)
# (trestbps _|_ restecg | fbs, thalach, exang, chol, sex, heartdisease)
# (trestbps _|_ thalach | fbs, restecg, exang, chol, sex, heartdisease)
# (trestbps _|_ chol | age, fbs, thalach, restecg, exang, sex, heartdisease)
# (trestbps _|_ restecg | age, fbs, thalach, exang, chol, sex, heartdisease)
# (trestbps _|_ thalach | age, fbs, restecg, exang, chol, sex, heartdisease)
# (fbs _|_ sex, exang)
# (fbs _|_ sex, trestbps, exang | age)
# (fbs _|_ sex | exang)
# (fbs _|_ exang | sex)
# (fbs _|_ restecg, chol, thalach | heartdisease)
# (fbs _|_ sex, trestbps | age, exang)
# (fbs _|_ trestbps, exang | age, sex)
# (fbs _|_ sex, exang | age, trestbps)
# (fbs _|_ restecg, chol, thalach | age, heartdisease)
# (fbs _|_ restecg, chol | heartdisease, thalach)
# (fbs _|_ chol, thalach | restecg, heartdisease)
# (fbs _|_ restecg, chol, thalach | exang, heartdisease)
# (fbs _|_ restecg, thalach | chol, heartdisease)
# (fbs _|_ restecg, chol, thalach | sex, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, heartdisease)
# (fbs _|_ sex, exang | age, trestbps, thalach)
# (fbs _|_ restecg, chol | age, heartdisease, thalach)
# (fbs _|_ sex, exang | age, trestbps, restecg)
# (fbs _|_ chol, thalach | age, restecg, heartdisease)
# (fbs _|_ trestbps | age, sex, exang)
# (fbs _|_ sex | age, trestbps, exang)
# (fbs _|_ restecg, chol, thalach | age, exang, heartdisease)
# (fbs _|_ sex, exang | age, trestbps, chol)
# (fbs _|_ restecg, thalach | age, chol, heartdisease)
# (fbs _|_ exang | age, sex, trestbps)
# (fbs _|_ restecg, chol, thalach | age, sex, heartdisease)
# (fbs _|_ chol, thalach, restecg, sex, exang | age, trestbps, heartdisease)
# (fbs _|_ chol | restecg, heartdisease, thalach)
# (fbs _|_ restecg, chol | exang, heartdisease, thalach)
# (fbs _|_ restecg | chol, heartdisease, thalach)
# (fbs _|_ restecg, chol | sex, heartdisease, thalach)
# (fbs _|_ restecg, chol | trestbps, heartdisease, thalach)
# (fbs _|_ chol, thalach | restecg, exang, heartdisease)
# (fbs _|_ thalach | restecg, chol, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, heartdisease)
# (fbs _|_ chol, thalach | restecg, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | chol, exang, heartdisease)
# (fbs _|_ restecg, chol, thalach | sex, exang, heartdisease)
# (fbs _|_ restecg, chol, thalach | trestbps, exang, heartdisease)
# (fbs _|_ restecg, thalach | sex, chol, heartdisease)
# (fbs _|_ restecg, thalach | trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol, thalach | sex, trestbps, heartdisease)
# (fbs _|_ sex, exang | age, trestbps, restecg, thalach)
# (fbs _|_ chol | age, restecg, heartdisease, thalach)
# (fbs _|_ sex | age, trestbps, exang, thalach)
# (fbs _|_ restecg, chol | age, exang, heartdisease, thalach)
# (fbs _|_ sex, exang | age, trestbps, chol, thalach)
# (fbs _|_ restecg | age, chol, heartdisease, thalach)
# (fbs _|_ exang | age, sex, trestbps, thalach)
# (fbs _|_ restecg, chol | age, sex, heartdisease, thalach)
# (fbs _|_ restecg, sex, chol, exang | age, trestbps, heartdisease, thalach)
# (fbs _|_ sex | age, trestbps, restecg, exang)
# (fbs _|_ chol, thalach | age, restecg, exang, heartdisease)
# (fbs _|_ sex, exang | age, trestbps, restecg, chol)
# (fbs _|_ thalach | age, heartdisease, restecg, chol)
# (fbs _|_ exang | age, sex, trestbps, restecg)
# (fbs _|_ chol, thalach | age, sex, restecg, heartdisease)
# (fbs _|_ sex, chol, exang, thalach | age, trestbps, restecg, heartdisease)
# (fbs _|_ sex | age, trestbps, chol, exang)
# (fbs _|_ restecg, thalach | age, chol, exang, heartdisease)
# (fbs _|_ restecg, chol, thalach | age, sex, exang, heartdisease)
# (fbs _|_ restecg, sex, chol, thalach | age, trestbps, exang, heartdisease)
# (fbs _|_ exang | age, sex, trestbps, chol)
# (fbs _|_ restecg, thalach | age, sex, chol, heartdisease)
# (fbs _|_ restecg, sex, exang, thalach | age, trestbps, chol, heartdisease)
# (fbs _|_ restecg, chol, exang, thalach | age, sex, trestbps, heartdisease)
# (fbs _|_ chol | restecg, exang, heartdisease, thalach)
# (fbs _|_ chol | restecg, sex, heartdisease, thalach)
# (fbs _|_ chol | restecg, trestbps, heartdisease, thalach)
# (fbs _|_ restecg | chol, exang, heartdisease, thalach)
# (fbs _|_ restecg, chol | sex, exang, heartdisease, thalach)
# (fbs _|_ restecg, chol | trestbps, exang, heartdisease, thalach)
# (fbs _|_ restecg | sex, chol, heartdisease, thalach)
# (fbs _|_ restecg | trestbps, chol, heartdisease, thalach)
# (fbs _|_ restecg, chol | sex, trestbps, heartdisease, thalach)
# (fbs _|_ thalach | restecg, chol, exang, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, exang, heartdisease)
# (fbs _|_ chol, thalach | restecg, trestbps, exang, heartdisease)
# (fbs _|_ thalach | restecg, sex, chol, heartdisease)
# (fbs _|_ thalach | restecg, trestbps, chol, heartdisease)
# (fbs _|_ chol, thalach | restecg, sex, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | sex, chol, exang, heartdisease)
# (fbs _|_ restecg, thalach | trestbps, chol, exang, heartdisease)
# (fbs _|_ restecg, chol, thalach | sex, trestbps, exang, heartdisease)
# (fbs _|_ restecg, thalach | sex, trestbps, chol, heartdisease)
# (fbs _|_ sex | age, thalach, restecg, exang, trestbps)
# (fbs _|_ chol | age, thalach, restecg, exang, heartdisease)
# (fbs _|_ sex, exang | age, thalach, restecg, chol, trestbps)
# (fbs _|_ exang | age, thalach, restecg, sex, trestbps)
# (fbs _|_ chol | age, thalach, restecg, sex, heartdisease)
# (fbs _|_ sex, chol, exang | age, thalach, restecg, trestbps, heartdisease)
# (fbs _|_ sex | age, thalach, exang, chol, trestbps)
# (fbs _|_ restecg | age, thalach, exang, chol, heartdisease)
# (fbs _|_ restecg, chol | age, thalach, exang, sex, heartdisease)
# (fbs _|_ restecg, sex, chol | age, thalach, exang, trestbps, heartdisease)
# (fbs _|_ exang | age, thalach, chol, sex, trestbps)
# (fbs _|_ restecg | age, thalach, chol, sex, heartdisease)
# (fbs _|_ restecg, sex, exang | age, thalach, chol, trestbps, heartdisease)
# (fbs _|_ restecg, chol, exang | age, thalach, sex, trestbps, heartdisease)
# (fbs _|_ sex | age, restecg, exang, chol, trestbps)
# (fbs _|_ thalach | age, restecg, exang, chol, heartdisease)
# (fbs _|_ chol, thalach | age, restecg, exang, sex, heartdisease)
# (fbs _|_ sex, chol, thalach | age, restecg, exang, trestbps, heartdisease)
# (fbs _|_ exang | age, restecg, chol, sex, trestbps)
# (fbs _|_ thalach | age, restecg, chol, sex, heartdisease)
# (fbs _|_ sex, exang, thalach | age, restecg, chol, trestbps, heartdisease)
# (fbs _|_ chol, exang, thalach | age, restecg, sex, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | age, exang, chol, sex, heartdisease)
# (fbs _|_ restecg, sex, thalach | age, exang, chol, trestbps, heartdisease)
# (fbs _|_ restecg, chol, thalach | age, exang, sex, trestbps, heartdisease)
# (fbs _|_ restecg, exang, thalach | age, chol, sex, trestbps, heartdisease)
# (fbs _|_ chol | thalach, restecg, exang, sex, heartdisease)
# (fbs _|_ chol | thalach, restecg, exang, trestbps, heartdisease)
# (fbs _|_ chol | thalach, restecg, sex, trestbps, heartdisease)
# (fbs _|_ restecg | thalach, exang, chol, sex, heartdisease)
# (fbs _|_ restecg | thalach, exang, chol, trestbps, heartdisease)
# (fbs _|_ restecg, chol | thalach, exang, sex, trestbps, heartdisease)
# (fbs _|_ restecg | thalach, chol, sex, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, exang, chol, sex, heartdisease)
# (fbs _|_ thalach | restecg, exang, chol, trestbps, heartdisease)
# (fbs _|_ chol, thalach | restecg, exang, sex, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, chol, sex, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | exang, chol, sex, trestbps, heartdisease)
# (fbs _|_ sex | age, thalach, restecg, exang, chol, trestbps)
# (fbs _|_ chol | age, thalach, restecg, exang, sex, heartdisease)
# (fbs _|_ sex, chol | age, thalach, restecg, exang, trestbps, heartdisease)
# (fbs _|_ exang | age, thalach, restecg, chol, sex, trestbps)
# (fbs _|_ sex, exang | age, thalach, restecg, chol, trestbps, heartdisease)
# (fbs _|_ chol, exang | age, thalach, restecg, sex, trestbps, heartdisease)
# (fbs _|_ restecg | age, thalach, exang, chol, sex, heartdisease)
# (fbs _|_ restecg, sex | age, thalach, exang, chol, trestbps, heartdisease)
# (fbs _|_ restecg, chol | age, thalach, exang, sex, trestbps, heartdisease)
# (fbs _|_ restecg, exang | age, thalach, chol, sex, trestbps, heartdisease)
# (fbs _|_ thalach | age, restecg, exang, chol, sex, heartdisease)
# (fbs _|_ sex, thalach | age, restecg, exang, chol, trestbps, heartdisease)
# (fbs _|_ chol, thalach | age, restecg, exang, sex, trestbps, heartdisease)
# (fbs _|_ exang, thalach | age, restecg, chol, sex, trestbps, heartdisease)
# (fbs _|_ restecg, thalach | age, exang, chol, sex, trestbps, heartdisease)
# (fbs _|_ chol | thalach, restecg, exang, sex, trestbps, heartdisease)
# (fbs _|_ restecg | thalach, exang, chol, sex, trestbps, heartdisease)
# (fbs _|_ thalach | restecg, exang, chol, sex, trestbps, heartdisease)
# (fbs _|_ sex | age, thalach, restecg, exang, chol, trestbps, heartdisease)
# (fbs _|_ chol | age, thalach, restecg, exang, sex, trestbps, heartdisease)
# (fbs _|_ exang | age, thalach, restecg, chol, sex, trestbps, heartdisease)
# (fbs _|_ restecg | age, thalach, exang, chol, sex, trestbps, heartdisease)
# (fbs _|_ thalach | age, restecg, exang, chol, sex, trestbps, heartdisease)
# (sex _|_ age, exang, fbs)
# (sex _|_ exang, fbs | age)
# (sex _|_ age, exang | fbs)
# (sex _|_ age, fbs | exang)
# (sex _|_ restecg, chol, thalach | heartdisease)
# (sex _|_ exang | age, fbs)
# (sex _|_ fbs | age, exang)
# (sex _|_ chol, fbs, thalach, restecg, heartdisease | age, trestbps)
# (sex _|_ restecg, chol, thalach | age, heartdisease)
# (sex _|_ age | exang, fbs)
# (sex _|_ restecg, chol, heartdisease, thalach | trestbps, fbs)
# (sex _|_ restecg, chol, thalach | heartdisease, fbs)
# (sex _|_ restecg, chol | heartdisease, thalach)
# (sex _|_ chol, thalach | restecg, heartdisease)
# (sex _|_ restecg, chol, thalach | exang, heartdisease)
# (sex _|_ restecg, thalach | chol, heartdisease)
# (sex _|_ restecg, chol, thalach | trestbps, heartdisease)
# (sex _|_ restecg, chol, heartdisease, thalach | age, trestbps, fbs)
# (sex _|_ restecg, chol, thalach | age, heartdisease, fbs)
# (sex _|_ restecg, heartdisease, chol, fbs | age, trestbps, thalach)
# (sex _|_ restecg, chol | age, heartdisease, thalach)
# (sex _|_ heartdisease, chol, fbs, thalach | age, trestbps, restecg)
# (sex _|_ chol, thalach | age, restecg, heartdisease)
# (sex _|_ chol, fbs, thalach, restecg, heartdisease | age, trestbps, exang)
# (sex _|_ restecg, chol, thalach | age, exang, heartdisease)
# ...
# (thalach _|_ sex, trestbps, fbs | age, restecg, exang, chol, heartdisease)
# (thalach _|_ fbs, trestbps, chol | age, restecg, exang, sex, heartdisease)
# (thalach _|_ sex, chol, fbs | age, restecg, exang, trestbps, heartdisease)
# (thalach _|_ exang | age, restecg, chol, sex, trestbps)
# (thalach _|_ trestbps, exang, fbs | age, restecg, chol, sex, heartdisease)
# (thalach _|_ sex, exang, fbs | age, restecg, chol, trestbps, heartdisease)
# (thalach _|_ chol, exang, fbs | age, restecg, sex, trestbps, heartdisease)
# (thalach _|_ restecg, trestbps, fbs | age, exang, chol, sex, heartdisease)
# (thalach _|_ restecg, sex, fbs | age, exang, chol, trestbps, heartdisease)
# (thalach _|_ restecg, chol, fbs | age, exang, sex, trestbps, heartdisease)
# (thalach _|_ restecg, exang, fbs | age, chol, sex, trestbps, heartdisease)
# (thalach _|_ age, sex | fbs, restecg, exang, chol, trestbps)
# (thalach _|_ age, sex, trestbps | fbs, restecg, exang, chol, heartdisease)
# (thalach _|_ age | fbs, restecg, exang, sex, trestbps)
# (thalach _|_ age, trestbps, chol | fbs, restecg, exang, sex, heartdisease)
# (thalach _|_ age, sex, chol | fbs, restecg, exang, trestbps, heartdisease)
# (thalach _|_ age, exang | fbs, restecg, chol, sex, trestbps)
# (thalach _|_ age, trestbps, exang | fbs, restecg, chol, sex, heartdisease)
# (thalach _|_ age, sex, exang | fbs, restecg, chol, trestbps, heartdisease)
# (thalach _|_ age, chol, exang | fbs, restecg, sex, trestbps, heartdisease)
# (thalach _|_ age | fbs, exang, chol, sex, trestbps)
# (thalach _|_ age, restecg, trestbps | fbs, exang, chol, sex, heartdisease)
# (thalach _|_ age, sex, restecg | fbs, exang, chol, trestbps, heartdisease)
# (thalach _|_ age, restecg, chol | fbs, exang, sex, trestbps, heartdisease)
# (thalach _|_ age, restecg, exang | fbs, chol, sex, trestbps, heartdisease)
# (thalach _|_ age, trestbps, fbs | restecg, exang, chol, sex, heartdisease)
# (thalach _|_ age, sex, fbs | restecg, exang, chol, trestbps, heartdisease)
# (thalach _|_ age, chol, fbs | restecg, exang, sex, trestbps, heartdisease)
# (thalach _|_ age, exang, fbs | restecg, chol, sex, trestbps, heartdisease)
# (thalach _|_ age, restecg, fbs | exang, chol, sex, trestbps, heartdisease)
# (thalach _|_ sex | age, fbs, restecg, exang, chol, trestbps)
# (thalach _|_ sex, trestbps | age, fbs, restecg, exang, chol, heartdisease)
# (thalach _|_ trestbps, chol | age, fbs, restecg, exang, sex, heartdisease)
# (thalach _|_ sex, chol | age, fbs, restecg, exang, trestbps, heartdisease)
# (thalach _|_ exang | age, fbs, restecg, chol, sex, trestbps)
# (thalach _|_ trestbps, exang | age, fbs, restecg, chol, sex, heartdisease)
# (thalach _|_ sex, exang | age, fbs, restecg, chol, trestbps, heartdisease)
# (thalach _|_ chol, exang | age, fbs, restecg, sex, trestbps, heartdisease)
# (thalach _|_ restecg, trestbps | age, fbs, exang, chol, sex, heartdisease)
# (thalach _|_ restecg, sex | age, fbs, exang, chol, trestbps, heartdisease)
# (thalach _|_ restecg, chol | age, fbs, exang, sex, trestbps, heartdisease)
# (thalach _|_ restecg, exang | age, fbs, chol, sex, trestbps, heartdisease)
# (thalach _|_ trestbps, fbs | age, restecg, exang, chol, sex, heartdisease)
# (thalach _|_ sex, fbs | age, restecg, exang, chol, trestbps, heartdisease)
# (thalach _|_ chol, fbs | age, restecg, exang, sex, trestbps, heartdisease)
# (thalach _|_ exang, fbs | age, restecg, chol, sex, trestbps, heartdisease)
# (thalach _|_ restecg, fbs | age, exang, chol, sex, trestbps, heartdisease)
# (thalach _|_ age | fbs, restecg, exang, chol, sex, trestbps)
# (thalach _|_ age, trestbps | fbs, restecg, exang, chol, sex, heartdisease)
# (thalach _|_ age, sex | fbs, restecg, exang, chol, trestbps, heartdisease)
# (thalach _|_ age, chol | fbs, restecg, exang, sex, trestbps, heartdisease)
# (thalach _|_ age, exang | fbs, restecg, chol, sex, trestbps, heartdisease)
# (thalach _|_ age, restecg | fbs, exang, chol, sex, trestbps, heartdisease)
# (thalach _|_ age, fbs | restecg, exang, chol, sex, trestbps, heartdisease)
# (thalach _|_ trestbps | age, fbs, restecg, exang, chol, sex, heartdisease)
# (thalach _|_ sex | age, fbs, restecg, exang, chol, trestbps, heartdisease)
# (thalach _|_ chol | age, fbs, restecg, exang, sex, trestbps, heartdisease)
# (thalach _|_ exang | age, fbs, restecg, chol, sex, trestbps, heartdisease)
# (thalach _|_ restecg | age, fbs, exang, chol, sex, trestbps, heartdisease)
# (thalach _|_ fbs | age, restecg, exang, chol, sex, trestbps, heartdisease)
# (thalach _|_ age | fbs, restecg, exang, chol, sex, trestbps, heartdisease)
# (chol _|_ age, fbs, thalach, restecg, sex, trestbps, exang | heartdisease)
# (chol _|_ sex, exang | age, trestbps)
# (chol _|_ fbs, thalach, restecg, sex, trestbps, exang | age, heartdisease)
# (chol _|_ age, sex, exang | trestbps, fbs)
# (chol _|_ age, thalach, restecg, sex, trestbps, exang | heartdisease, fbs)
# (chol _|_ age, fbs, restecg, sex, trestbps, exang | heartdisease, thalach)
# (chol _|_ age, fbs, thalach, sex, trestbps, exang | restecg, heartdisease)
# (chol _|_ age, fbs, thalach, restecg, sex, trestbps | exang, heartdisease)
# (chol _|_ age, fbs, thalach, restecg, trestbps, exang | sex, heartdisease)
# (chol _|_ age, fbs, thalach, restecg, sex, exang | trestbps, heartdisease)
# (chol _|_ sex, exang | age, trestbps, fbs)
# (chol _|_ thalach, restecg, sex, trestbps, exang | age, heartdisease, fbs)
# (chol _|_ sex, exang | age, trestbps, thalach)
# (chol _|_ fbs, restecg, sex, trestbps, exang | age, heartdisease, thalach)
# (chol _|_ sex, exang | age, trestbps, restecg)
# (chol _|_ fbs, thalach, sex, trestbps, exang | age, restecg, heartdisease)
# (chol _|_ sex | age, trestbps, exang)
# (chol _|_ fbs, thalach, restecg, sex, trestbps | age, exang, heartdisease)
# (chol _|_ exang | age, sex, trestbps)
# (chol _|_ fbs, thalach, restecg, trestbps, exang | age, sex, heartdisease)
# (chol _|_ fbs, thalach, restecg, sex, exang | age, trestbps, heartdisease)
# (chol _|_ age, sex, exang | trestbps, fbs, thalach)
# (chol _|_ age, restecg, sex, trestbps, exang | heartdisease, fbs, thalach)
# (chol _|_ age, sex, exang | restecg, trestbps, fbs)
# (chol _|_ age, thalach, sex, trestbps, exang | restecg, heartdisease, fbs)
# (chol _|_ age, sex | trestbps, exang, fbs)
# (chol _|_ age, thalach, restecg, sex, trestbps | heartdisease, exang, fbs)
# (chol _|_ age, exang | sex, trestbps, fbs)
# (chol _|_ age, thalach, restecg, trestbps, exang | sex, heartdisease, fbs)
# (chol _|_ age, thalach, restecg, sex, exang | heartdisease, trestbps, fbs)
# (chol _|_ age, fbs, sex, trestbps, exang | restecg, heartdisease, thalach)
# (chol _|_ age, fbs, restecg, sex, trestbps | exang, heartdisease, thalach)
# (chol _|_ age, fbs, restecg, trestbps, exang | sex, heartdisease, thalach)
# (chol _|_ age, fbs, restecg, sex, exang | trestbps, heartdisease, thalach)
# (chol _|_ age, fbs, thalach, sex, trestbps | restecg, exang, heartdisease)
# (chol _|_ age, fbs, thalach, trestbps, exang | restecg, sex, heartdisease)
# (chol _|_ age, fbs, thalach, sex, exang | restecg, trestbps, heartdisease)
# (chol _|_ age, fbs, thalach, restecg, trestbps | sex, exang, heartdisease)
# (chol _|_ age, fbs, thalach, restecg, sex | trestbps, exang, heartdisease)
# (chol _|_ age, fbs, thalach, restecg, exang | sex, trestbps, heartdisease)
# (chol _|_ sex, exang | age, trestbps, fbs, thalach)
# (chol _|_ restecg, sex, trestbps, exang | age, heartdisease, fbs, thalach)
# (chol _|_ sex, exang | age, trestbps, restecg, fbs)
# (chol _|_ sex, trestbps, exang, thalach | age, heartdisease, restecg, fbs)
# (chol _|_ sex | age, trestbps, exang, fbs)
# (chol _|_ restecg, sex, trestbps, thalach | age, heartdisease, exang, fbs)
# (chol _|_ exang | age, sex, trestbps, fbs)
# (chol _|_ restecg, trestbps, exang, thalach | age, sex, heartdisease, fbs)
# (chol _|_ restecg, sex, exang, thalach | age, heartdisease, trestbps, fbs)
# (chol _|_ sex, exang | age, trestbps, restecg, thalach)
# (chol _|_ sex, trestbps, exang, fbs | age, restecg, heartdisease, thalach)
# (chol _|_ sex | age, trestbps, exang, thalach)
# (chol _|_ restecg, sex, trestbps, fbs | age, exang, heartdisease, thalach)
# (chol _|_ exang | age, sex, trestbps, thalach)
# (chol _|_ restecg, trestbps, exang, fbs | age, sex, heartdisease, thalach)
# (chol _|_ restecg, sex, exang, fbs | age, trestbps, heartdisease, thalach)
# (chol _|_ sex | age, trestbps, restecg, exang)
# (chol _|_ sex, trestbps, fbs, thalach | age, restecg, exang, heartdisease)
# (chol _|_ exang | age, sex, trestbps, restecg)
# (chol _|_ trestbps, exang, fbs, thalach | age, sex, restecg, heartdisease)
# (chol _|_ sex, exang, fbs, thalach | age, trestbps, restecg, heartdisease)
# (chol _|_ restecg, trestbps, fbs, thalach | age, sex, exang, heartdisease)
# (chol _|_ restecg, sex, fbs, thalach | age, trestbps, exang, heartdisease)
# (chol _|_ restecg, exang, fbs, thalach | age, sex, trestbps, heartdisease)
# (chol _|_ age, sex, exang | restecg, trestbps, fbs, thalach)
# (chol _|_ age, sex, trestbps, exang | restecg, heartdisease, fbs, thalach)
# (chol _|_ age, sex | trestbps, exang, fbs, thalach)
# (chol _|_ age, sex, restecg, trestbps | heartdisease, exang, fbs, thalach)
# (chol _|_ age, exang | sex, trestbps, fbs, thalach)
# (chol _|_ age, restecg, trestbps, exang | sex, heartdisease, fbs, thalach)
# (chol _|_ age, sex, restecg, exang | heartdisease, trestbps, fbs, thalach)
# (chol _|_ age, sex | restecg, trestbps, exang, fbs)
# (chol _|_ age, sex, trestbps, thalach | restecg, heartdisease, exang, fbs)
# (chol _|_ age, exang | restecg, sex, trestbps, fbs)
# (chol _|_ age, trestbps, exang, thalach | restecg, sex, heartdisease, fbs)
# (chol _|_ age, sex, exang, thalach | restecg, heartdisease, trestbps, fbs)
# (chol _|_ age | sex, trestbps, exang, fbs)
# (chol _|_ age, restecg, trestbps, thalach | sex, heartdisease, exang, fbs)
# (chol _|_ age, sex, restecg, thalach | heartdisease, trestbps, exang, fbs)
# (chol _|_ age, restecg, exang, thalach | sex, heartdisease, trestbps, fbs)
# (chol _|_ age, sex, trestbps, fbs | restecg, exang, heartdisease, thalach)
# (chol _|_ age, trestbps, exang, fbs | restecg, sex, heartdisease, thalach)
# (chol _|_ age, sex, exang, fbs | restecg, trestbps, heartdisease, thalach)
# (chol _|_ age, restecg, trestbps, fbs | sex, exang, heartdisease, thalach)
# (chol _|_ age, sex, restecg, fbs | trestbps, exang, heartdisease, thalach)
# (chol _|_ age, restecg, exang, fbs | sex, trestbps, heartdisease, thalach)
# (chol _|_ age, trestbps, fbs, thalach | restecg, sex, exang, heartdisease)
# (chol _|_ age, sex, fbs, thalach | restecg, trestbps, exang, heartdisease)
# (chol _|_ age, exang, fbs, thalach | restecg, sex, trestbps, heartdisease)
# (chol _|_ age, restecg, fbs, thalach | sex, trestbps, exang, heartdisease)
# (chol _|_ sex, exang | age, fbs, thalach, restecg, trestbps)
# (chol _|_ sex, trestbps, exang | age, fbs, thalach, restecg, heartdisease)
# (chol _|_ sex | age, fbs, thalach, exang, trestbps)
# (chol _|_ restecg, sex, trestbps | age, fbs, thalach, exang, heartdisease)
# (chol _|_ exang | age, fbs, thalach, sex, trestbps)
# (chol _|_ restecg, trestbps, exang | age, fbs, thalach, sex, heartdisease)
# (chol _|_ restecg, sex, exang | age, fbs, thalach, trestbps, heartdisease)
# (chol _|_ sex | age, fbs, restecg, exang, trestbps)
# (chol _|_ sex, trestbps, thalach | age, fbs, restecg, exang, heartdisease)
# (chol _|_ exang | age, fbs, restecg, sex, trestbps)
# (chol _|_ trestbps, exang, thalach | age, fbs, restecg, sex, heartdisease)
# (chol _|_ sex, exang, thalach | age, fbs, restecg, trestbps, heartdisease)
# (chol _|_ restecg, trestbps, thalach | age, fbs, exang, sex, heartdisease)
# (chol _|_ restecg, sex, thalach | age, fbs, exang, trestbps, heartdisease)
# (chol _|_ restecg, exang, thalach | age, fbs, sex, trestbps, heartdisease)
# (chol _|_ sex | age, thalach, restecg, exang, trestbps)
# (chol _|_ sex, trestbps, fbs | age, thalach, restecg, exang, heartdisease)
# (chol _|_ exang | age, thalach, restecg, sex, trestbps)
# (chol _|_ trestbps, exang, fbs | age, thalach, restecg, sex, heartdisease)
# (chol _|_ sex, exang, fbs | age, thalach, restecg, trestbps, heartdisease)
# (chol _|_ restecg, trestbps, fbs | age, thalach, exang, sex, heartdisease)
# (chol _|_ restecg, sex, fbs | age, thalach, exang, trestbps, heartdisease)
# (chol _|_ restecg, exang, fbs | age, thalach, sex, trestbps, heartdisease)
# (chol _|_ trestbps, fbs, thalach | age, restecg, exang, sex, heartdisease)
# (chol _|_ sex, fbs, thalach | age, restecg, exang, trestbps, heartdisease)
# (chol _|_ exang, fbs, thalach | age, restecg, sex, trestbps, heartdisease)
# (chol _|_ restecg, fbs, thalach | age, exang, sex, trestbps, heartdisease)
# (chol _|_ age, sex | fbs, thalach, restecg, exang, trestbps)
# (chol _|_ age, sex, trestbps | fbs, thalach, restecg, exang, heartdisease)
# (chol _|_ age, exang | fbs, thalach, restecg, sex, trestbps)
# (chol _|_ age, trestbps, exang | fbs, thalach, restecg, sex, heartdisease)
# (chol _|_ age, sex, exang | fbs, thalach, restecg, trestbps, heartdisease)
# (chol _|_ age | fbs, thalach, exang, sex, trestbps)
# (chol _|_ age, restecg, trestbps | fbs, thalach, exang, sex, heartdisease)
# (chol _|_ age, sex, restecg | fbs, thalach, exang, trestbps, heartdisease)
# (chol _|_ age, restecg, exang | fbs, thalach, sex, trestbps, heartdisease)
# (chol _|_ age | fbs, restecg, exang, sex, trestbps)
# (chol _|_ age, trestbps, thalach | fbs, restecg, exang, sex, heartdisease)
# (chol _|_ age, sex, thalach | fbs, restecg, exang, trestbps, heartdisease)
# (chol _|_ age, exang, thalach | fbs, restecg, sex, trestbps, heartdisease)
# (chol _|_ age, restecg, thalach | fbs, exang, sex, trestbps, heartdisease)
# (chol _|_ age, trestbps, fbs | thalach, restecg, exang, sex, heartdisease)
# (chol _|_ age, sex, fbs | thalach, restecg, exang, trestbps, heartdisease)
# (chol _|_ age, exang, fbs | thalach, restecg, sex, trestbps, heartdisease)
# (chol _|_ age, restecg, fbs | thalach, exang, sex, trestbps, heartdisease)
# (chol _|_ age, fbs, thalach | restecg, exang, sex, trestbps, heartdisease)
# (chol _|_ sex | age, fbs, thalach, restecg, exang, trestbps)
# (chol _|_ sex, trestbps | age, fbs, thalach, restecg, exang, heartdisease)
# (chol _|_ exang | age, fbs, thalach, restecg, sex, trestbps)
# (chol _|_ trestbps, exang | age, fbs, thalach, restecg, sex, heartdisease)
# (chol _|_ sex, exang | age, fbs, thalach, restecg, trestbps, heartdisease)
# (chol _|_ restecg, trestbps | age, fbs, thalach, exang, sex, heartdisease)
# (chol _|_ restecg, sex | age, fbs, thalach, exang, trestbps, heartdisease)
# (chol _|_ restecg, exang | age, fbs, thalach, sex, trestbps, heartdisease)
# (chol _|_ trestbps, thalach | age, fbs, restecg, exang, sex, heartdisease)
# (chol _|_ sex, thalach | age, fbs, restecg, exang, trestbps, heartdisease)
# (chol _|_ exang, thalach | age, fbs, restecg, sex, trestbps, heartdisease)
# (chol _|_ restecg, thalach | age, fbs, exang, sex, trestbps, heartdisease)
# (chol _|_ trestbps, fbs | age, thalach, restecg, exang, sex, heartdisease)
# (chol _|_ sex, fbs | age, thalach, restecg, exang, trestbps, heartdisease)
# (chol _|_ exang, fbs | age, thalach, restecg, sex, trestbps, heartdisease)
# (chol _|_ restecg, fbs | age, thalach, exang, sex, trestbps, heartdisease)
# (chol _|_ fbs, thalach | age, restecg, exang, sex, trestbps, heartdisease)
# (chol _|_ age | fbs, thalach, restecg, exang, sex, trestbps)
# (chol _|_ age, trestbps | fbs, thalach, restecg, exang, sex, heartdisease)
# (chol _|_ age, sex | fbs, thalach, restecg, exang, trestbps, heartdisease)
# (chol _|_ age, exang | fbs, thalach, restecg, sex, trestbps, heartdisease)
# (chol _|_ age, restecg | fbs, thalach, exang, sex, trestbps, heartdisease)
# (chol _|_ age, thalach | fbs, restecg, exang, sex, trestbps, heartdisease)
# (chol _|_ age, fbs | thalach, restecg, exang, sex, trestbps, heartdisease)
# (chol _|_ trestbps | age, fbs, thalach, restecg, exang, sex, heartdisease)
# (chol _|_ sex | age, fbs, thalach, restecg, exang, trestbps, heartdisease)
# (chol _|_ exang | age, fbs, thalach, restecg, sex, trestbps, heartdisease)
# (chol _|_ restecg | age, fbs, thalach, exang, sex, trestbps, heartdisease)
# (chol _|_ thalach | age, fbs, restecg, exang, sex, trestbps, heartdisease)
# (chol _|_ fbs | age, thalach, restecg, exang, sex, trestbps, heartdisease)
# (chol _|_ age | fbs, thalach, restecg, exang, sex, trestbps, heartdisease)

# %%
from pgmpy.inference import VariableElimination

HeartDisease_infer = VariableElimination(model)

# %%
q = HeartDisease_infer.query(variables=['heartdisease'], evidence={'age': 28})
print(q['heartdisease'])
# Out:
# +----------------+---------------------+
# | heartdisease   |   phi(heartdisease) |
# +================+=====================+
# | heartdisease_0 |              0.6333 |
# +----------------+---------------------+
# | heartdisease_1 |              0.3667 |
# +----------------+---------------------+
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:598: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi1.values = phi1.values[slice_]
# /home/akshayrb22/.local/lib/python3.7/site-packages/pgmpy/factors/discrete/DiscreteFactor.py:586: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   phi.values = phi.values[slice_]

# %%
q = HeartDisease_infer.query(variables=['heartdisease'],
                             evidence={'chol': 100})
print(q['heartdisease'])
# Out:
# +----------------+---------------------+
# | heartdisease   |   phi(heartdisease) |
# +================+=====================+
# | heartdisease_0 |              1.0000 |
# +----------------+---------------------+
# | heartdisease_1 |              0.0000 |
# +----------------+---------------------+
